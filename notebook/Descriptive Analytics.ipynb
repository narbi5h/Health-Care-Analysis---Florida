# %%
# Core
import pandas as pd
import numpy as np
from dotenv import load_dotenv

# Pretty printing indented tables
from textwrap import indent

# Database
from sqlalchemy import create_engine, text
import os

# %% [markdown]
# ---
#
# ## 🧩 **DB Connection**
#
# **Goal:** Establish a secure connection to the PostgreSQL database using credentials stored in an environment variable (`DB_URL`).
#
#  - Storing credentials as environment variables prevents exposing sensitive information like usernames, passwords, and host details directly in the source code.
#  - This ensures better security and easier configuration across different environments (local, staging, production).
#
# ---

# %%
'''************************************* DB CONNECTION *********************************'''

# 1) Connect to DB  (edit credentials as needed)

#### Database Connection Setup

# Load credentials (like DB_USER, DB_PASS, etc.) from the .env file
load_dotenv()

# Retrieve database credentials from environment variables
DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

# Build the PostgreSQL connection string dynamically using credentials
DB_URL = f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# Initialize the SQLAlchemy engine to manage the connection to the database
# 'pool_pre_ping=True' ensures stale connections are checked before use
engine = create_engine(DB_URL, pool_pre_ping=True)

# Confirm successful connection
print("The connection to the DB has been successfully established ✅")
# Out:
# The connection to the DB has been successfully established ✅

# %%
'''************************************* DATA LOADING *********************************'''

# This block:
# - Prints a start message
# - Builds a list of columns to fetch
# - Constructs a SQL SELECT query
# - Streams the data from PostgreSQL in chunks using pandas.read_sql()
# - Concatenates all chunks into one DataFrame
# - Prints a success message

print("data loading started.......")

# Define the columns to select (quoted and aliased where needed for clarity)
COLS_SQL = """
    hospital_name,
    "ZIP4"                           AS zip4,
    setting,
    standard_charge_gross,
    standard_charge_discounted_cash,
    payer_name,
    plan_name,
    standard_charge_negotiated_dollar,
    standard_charge_negotiated_percentage,
    standard_charge_min,
    standard_charge_max,
    bucket,
    specification,
    cpt_code,
    "Simple Description"             AS category,
    "Specialty"                      AS specialty,
    "Rate_using_min"                 AS rate_using_min,
    "Rate_using_max"                 AS rate_using_max
"""

# Construct the SQL query string
query = text(f"SELECT {COLS_SQL} FROM standardized_cpt_columns")

# Read data from PostgreSQL in chunks and combine into one DataFrame
chunks = pd.read_sql(query, engine, chunksize=100_000)
df = pd.concat(chunks, ignore_index=True)

# Print confirmation message once data is successfully loaded
print("data loading successful ✅ ")
# Out:
# data loading started.......
# C:\Users\ss318889\AppData\Local\Temp\ipykernel_15368\97668723.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(chunks, ignore_index=True)
# data loading successful ✅

# %%
#********************************************* COERCE NUMERICAL COLUMNS *******************************

# This block:
# - Prints a start message
# - Defines which columns should be numeric
# - Converts each to numeric type safely
# - Replaces bad data with NaN
# - Prints a success message

print("numeric conversion started ✅ ")

numeric_cols = [
    "standard_charge_gross",
    "standard_charge_discounted_cash",
    "standard_charge_negotiated_dollar",
    "estimated_amount",
    "standard_charge_min",
    "standard_charge_max",
    "Rate_using_min",
    "Rate_using_max"
]

for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce")

print("numeric conversion successful ✅ ")
# Out:
# numeric conversion started ✅
# numeric conversion successful ✅

# %% [markdown]
# ---
#
# ## 📊 **Part A: Basic Summary Statistics**
#
# **This section prints:**
# - **Shape:** total number of rows and columns.
# - **Missing values (by column):** count **and** % missing, sorted by highest %.
# - **Data types (per column):** full dtype listing.
# - **Dtype family counts:** how many columns are `object`, `float`, `int`, `bool`, `datetime`, etc.
# - **Column-type overview:** counts of **numeric**, **categorical (object/category)**, and **datetime** columns.
# - **Unique counts for key identifiers:** `hospital_name`, `payer_name`, `plan_name`, `cpt_code`, `specialty`
#   - Gracefully skips any that aren’t present (prints a friendly note).
# - **Top-5 most frequent values** for each key identifier (when the column exists).
# - **Missing negotiated rates:** % of rows where **both** `standard_charge_negotiated_dollar` **and** `standard_charge_negotiated_percentage` are missing.
# - **Completion notice** confirming the summary finished.
#
# ---

# %%
# ========================================= BASIC SUMMARY STATISTICS =========================================
# This code systematically:
# - Reports dataset dimensions.
# - Calculates missing values (counts & percentages).
# - Shows data types and summaries by type.
# - Counts unique and frequent values for important identifier columns.
# - Detects missing negotiated rate info.
# - Prints all findings in clean, labeled sections.

print("\n" + "="*80)
print("A) SHAPE OF DATA (rows, columns)")
print("="*80)
n_rows, n_cols = df.shape
print(f"→ The dataset has {n_rows:,} rows and {n_cols:,} columns.\n")

print("="*80)
print("B) MISSING VALUES OVERVIEW (by column)")
print("="*80)
# Build a summary table with null counts and percentages, sorted by highest % missing
null_counts = df.isnull().sum()
null_pct = (null_counts / len(df) * 100).round(2)
null_summary = (
    pd.DataFrame({"null_count": null_counts, "null_pct": null_pct})
    .sort_values("null_pct", ascending=False)
)
print("→ Null count and % of missing values for each column (sorted by % missing):")
print(null_summary.to_string())
print()  # spacing

print("="*80)
print("C) DATA TYPES (per column) + dtype family counts")
print("="*80)
# Print the dtype of each column
dtype_series = df.dtypes.astype(str)
print("→ Data types for each column:")
print(dtype_series.to_string())
print()

# Also provide a quick tally of major dtype families (object, float, int, bool, datetime, etc.)
dtype_family_counts = dtype_series.value_counts()
print("→ Count of columns by dtype family:")
print(dtype_family_counts.to_string())
print()

# Quick view of numeric vs. categorical column counts
num_cols = df.select_dtypes(include=["number"]).columns.tolist()
cat_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
dt_cols  = df.select_dtypes(include=["datetime64[ns]", "datetimetz"]).columns.tolist()
print(f"→ Numeric columns: {len(num_cols)}")
print(f"→ Categorical (object/category) columns: {len(cat_cols)}")
print(f"→ Datetime columns: {len(dt_cols)}\n")

print("="*80)
print("D) UNIQUE COUNTS FOR KEY IDENTIFIERS")
print("="*80)

def safe_unique_count(frame: pd.DataFrame, col_name: str) -> int | None:
    """
    Returns the number of unique non-null values for `col_name` if the column exists.
    Prints a friendly note if it doesn't, and returns None.
    """
    if col_name in frame.columns:
        return frame[col_name].nunique(dropna=True)
    else:
        print(f"• Column '{col_name}' was NOT found in the dataframe.")
        return None

key_cols = ["hospital_name", "payer_name", "plan_name", "cpt_code", "specialty"]

unique_counts = {}
for c in key_cols:
    unique_counts[c] = safe_unique_count(df, c)

# Pretty-print the results
print("→ Unique non-null value counts:")
for c in key_cols:
    val = unique_counts[c]
    if val is not None:
        print(f"• {c}: {val:,}")

# Top 5 most frequent values for each key column
print("\n→ Top 5 most frequent values (for columns that exist):")
for c in key_cols:
    if c in df.columns:
        vc = df[c].value_counts(dropna=True).head(5)
        print(f"\n• {c} (top 5):")
        print(indent(vc.to_string(), prefix="  "))

# --- Additional Datapoint: Missing negotiated rates  ---
print("="*80)
print("E) MISSING NEGOTIATED RATES ")
print("="*80)

col_dollar = "standard_charge_negotiated_dollar"
col_pct = "standard_charge_negotiated_percentage"

if col_dollar in df.columns and col_pct in df.columns:
    # Rows where BOTH negotiated dollar and percentage are null
    mask_missing_negotiated = df[col_dollar].isna() & df[col_pct].isna()
    missing_count = mask_missing_negotiated.sum()
    total_rows = len(df)
    missing_pct = (missing_count / total_rows * 100).round(2)

    print(f"→ Rows with BOTH negotiated dollar and percentage missing: {missing_count:,}")
    print(f"→ That’s {missing_pct}% of all records with no negotiated price information.")
else:
    print("⚠️ Columns for negotiated rates not found — skipping this datapoint.")

# Display first 5 unique hospitals (for a quick check)
print("\n→ First 5 unique hospital names:")
if "hospital_name" in df.columns:
    print(df["hospital_name"].dropna().unique()[:5])
else:
    print("⚠️ Column 'hospital_name' not found in the dataset.")

print("\n✅ Basic summary statistics complete.\n")
# Out:
# ================================================================================
# A) SHAPE OF DATA (rows, columns)
# ================================================================================
# → The dataset has 10,209,983 rows and 18 columns.
#
# ================================================================================
# B) MISSING VALUES OVERVIEW (by column)
# ================================================================================
# → Null count and % of missing values for each column (sorted by % missing):
#                                        null_count  null_pct
# standard_charge_negotiated_percentage     8281917     81.12
# standard_charge_negotiated_dollar         7534333     73.79
# standard_charge_discounted_cash           5757091     56.39
# standard_charge_gross                     5701013     55.84
# standard_charge_min                        541964      5.31
# standard_charge_max                        488148      4.78
# rate_using_max                              55098      0.54
# rate_using_min                              55098      0.54
# zip4                                        22319      0.22
# plan_name                                     740      0.01
# hospital_name                                   0      0.00
# payer_name                                     19      0.00
# setting                                         0      0.00
# bucket                                         19      0.00
# cpt_code                                        0      0.00
# specification                                  19      0.00
# specialty                                       0      0.00
# category                                        0      0.00
#
# ================================================================================
# C) DATA TYPES (per column) + dtype family counts
# ================================================================================
# → Data types for each column:
# hospital_name                             object
# zip4                                      object
# setting                                   object
# standard_charge_gross                    float64
# standard_charge_discounted_cash          float64
# payer_name                                object
# plan_name                                 object
# standard_charge_negotiated_dollar        float64
# standard_charge_negotiated_percentage    float64
# standard_charge_min                      float64
# standard_charge_max                      float64
# bucket                                    object
# specification                             object
# cpt_code                                  object
# category                                  object
# specialty                                 object
# rate_using_min                           float64
# rate_using_max                           float64
#
# → Count of columns by dtype family:
# object     10
# float64     8
#
# → Numeric columns: 8
# → Categorical (object/category) columns: 10
# → Datetime columns: 0
#
# ================================================================================
# D) UNIQUE COUNTS FOR KEY IDENTIFIERS
# ================================================================================
# → Unique non-null value counts:
# • hospital_name: 157
# • payer_name: 919
# • plan_name: 2,040
# • cpt_code: 111
# • specialty: 11
#
# → Top 5 most frequent values (for columns that exist):
#
# • hospital_name (top 5):
#   hospital_name
#   HCA FLORIDA OCALA HOSPITAL          773958
#   HCA FLORIDA WEST HOSPITAL           596184
#   HCA FLORIDA MEMORIAL HOSPITAL       590704
#   HCA FLORIDA LAKE MONROE HOSPITAL    524348
#   HCA FLORIDA TRINITY HOSPITAL        519804
#
# • payer_name (top 5):
#   payer_name
#   bcbs      596590
#   united    570025
#   humana    499897
#   aetna     368573
#   cigna     353990
#
# • plan_name (top 5):
#   plan_name
#   ppo                350333
#   mgmcr              264504
#   hix                227021
#   hmo                219552
#   health plan mcr    200906
#
# • cpt_code (top 5):
#   cpt_code
#   90853    289926
#   97530    243747
#   97110    224136
#   97535    213158
#   97140    203762
#
# • specialty (top 5):
#   specialty
#   Physical Medicine & Rehabilitation    1616158
#   Emergency Medicine                    1256749
#   Orthopedic Surgery                    1236185
#   Cardiology                            1081029
#   Urology                                951833
# ================================================================================
# E) MISSING NEGOTIATED RATES
# ================================================================================
# → Rows with BOTH negotiated dollar and percentage missing: 6,587,333
# → That’s 64.52% of all records with no negotiated price information.
#
# → First 5 unique hospital names:
# ['HCA FLORIDA NORTH FLORIDA HOSPITAL' 'HCA FLORIDA BAYONET POINT HOSPITAL'
#  'HCA FLORIDA ORANGE PARK HOSPITAL' 'Lower Keys Medical Center'
#  'HCA FLORIDA BLAKE HOSPITAL']
#
# ✅ Basic summary statistics complete.

# %% [markdown]
# ---
#
# ## 📈 **Part B: Meaningful Numeric Insights**
#
# **Goal:** Move beyond `.describe()` to compute interpretable pricing insights.
#
# 1. **Pricing variability**
#    - Standard deviation, coefficient of variation (CV), min–max range, and IQR.
# 2. **Extremes with context**
#    - Top/bottom negotiated prices **with** associated `hospital`, `payer`, and `cpt_code`.
# 3. **Payer-bucket view** *(optional but useful)*
#    - Quick breakdown by bucket (Commercial / Government / Self-pay).
#
# ---

# %%
# ====================================== PART B — MEANINGFUL NUMERIC INSIGHTS ======================================
# ✅ In summary:
# This block:
# - Formats all numbers neatly for easier readability.
# - Selects relevant charge columns (robust to missing ones).
# - Calculates descriptive & advanced statistics (CV, IQR, range).
# - Creates a clean, extended summary table for easy interpretation.
# - Prepares variable shortcuts for next analyses.

pd.set_option("display.float_format", lambda x: f"{x:,.2f}")

# ---- 0) Choose price columns that exist in your DF (robust to missing columns) -------
candidate_charge_cols = [
    "standard_charge_gross",
    "standard_charge_discounted_cash",
    "standard_charge_negotiated_dollar",
    "standard_charge_min",
    "standard_charge_max",
    "Rate_using_min",
    "Rate_using_max",
]
charge_cols = [c for c in candidate_charge_cols if c in df.columns]

print("\n" + "="*100)
print("PART B — MEANINGFUL NUMERIC INSIGHTS")
print("="*100)
print(f"Using {len(charge_cols)} charge columns:", charge_cols)

# ---- 1) Overall focused summary (mean/median/std/min/max + CV + Range + IQR) ---------
print("\n" + "-"*100)
print("B1) OVERALL SUMMARY with CV (std/mean), Range, and IQR (75th–25th)")
print("-"*100)

summary = df[charge_cols].agg(["count", "mean", "median", "std", "min", "max"])
# Add CV, Range, IQR
q25 = df[charge_cols].quantile(0.25)
q75 = df[charge_cols].quantile(0.75)
cv = summary.loc["std"] / summary.loc["mean"]
_rng = summary.loc["max"] - summary.loc["min"]
iqr = q75 - q25

# Build a tidy table
summary_extended = (
    pd.concat(
        {
            "count": summary.loc["count"],
            "mean": summary.loc["mean"],
            "median": summary.loc["median"],
            "std": summary.loc["std"],
            "cv_std_over_mean": cv,
            "min": summary.loc["min"],
            "q25": q25,
            "q75": q75,
            "iqr": iqr,
            "max": summary.loc["max"],
            "range_max_minus_min": _rng,
        },
        axis=1,
    )
    .round(2)
)

print("→ Focused numeric snapshot (columns as rows):")
print(indent(summary_extended.to_string(), "  "))

# Set variable shortcuts for easier reference later
g = "standard_charge_gross"
cash = "standard_charge_discounted_cash"
neg = "standard_charge_negotiated_dollar"
# Out:
# ====================================================================================================
# PART B — MEANINGFUL NUMERIC INSIGHTS
# ====================================================================================================
# Using 5 charge columns: ['standard_charge_gross', 'standard_charge_discounted_cash', 'standard_charge_negotiated_dollar', 'standard_charge_min', 'standard_charge_max']
#
# ----------------------------------------------------------------------------------------------------
# B1) OVERALL SUMMARY with CV (std/mean), Range, and IQR (75th–25th)
# ----------------------------------------------------------------------------------------------------
# → Focused numeric snapshot (columns as rows):
#                                            count      mean   median       std  cv_std_over_mean  min    q25       q75       iqr          max  range_max_minus_min
#   standard_charge_gross             4,508,970.00  6,800.75   944.40 16,951.12              2.49 1.00 339.00  4,400.00  4,061.00   400,176.50           400,175.50
#   standard_charge_discounted_cash   4,452,892.00  4,472.06   624.75 12,045.57              2.69 0.20 210.18  2,773.26  2,563.08   213,209.45           213,209.25
#   standard_charge_negotiated_dollar 2,675,650.00  5,352.60 1,301.88 21,680.36              4.05 0.95 198.90  5,831.00  5,632.10 9,593,845.00         9,593,844.05
#   standard_charge_min               9,668,019.00  3,141.49 1,728.00  5,321.91              1.69 0.01 213.83  3,375.90  3,162.07   108,919.00           108,918.99
#   standard_charge_max               9,721,835.00 13,214.15 5,769.56 86,019.59              6.51 0.01 677.00 14,540.00 13,863.00 9,593,845.00         9,593,844.99

# %% [markdown]
# ---
#
# ## 🧪 **Part B+: Specialty & CPT Formatted Summaries**
#
# **What this section does**
#
# - **Canonical specialty list**
#   Uses a fixed set of specialties: Dermatology, Ophthalmology, Orthopedic, Physical Medicine & Rehabilitation, Psychiatry/Psychology, Radiation Oncology.
#
#
# - **Specialty & CPT report**
#   `specialty_and_cpt_report(...)`:
#   1. Filters to a single canonical specialty (`specialty_canon == <label>`).
#   2. Prints a **specialty-level** numeric summary using the helper.
#   3. Handles CPTs:
#      - If `cpt_code` exists, summarizes selected CPTs; if none provided, auto-selects the **top `k` CPTs** by frequency (`top_k_cpts=2` by default).
#      - Skips gracefully if `cpt_code` is absent.
#
# - **Batch run over all specialties**
#   Iterates through every item in the canonical list and generates the specialty + top-CPT summaries, reusing `charge_cols` from Part B.
#
# ---

# %%
# ====================================== PART B+: SPECIALTY & CPT FORMATTED SUMMARIES ======================================
# ✅ In summary:
# This block:
# - Defines a canonical list of medical specialties to standardize naming across the dataset.
# - Normalizes inconsistent or messy specialty spellings (e.g., extra spaces, “&” → “and”, etc.).
# - Builds a lookup dictionary to map normalized specialty names to clean, canonical labels.
# - Adds a new non-destructive column `specialty_canon` to store standardized specialty names.
# - Defines a reusable helper function `_make_numeric_summary()` to compute numeric stats:
#     - count, mean, median, std, min, max, 25th percentile (q25), 75th percentile (q75),
#       interquartile range (IQR), range, and coefficient of variation (CV = std/mean).
# - Defines a main report function `specialty_and_cpt_report()` that:
#     1. Filters the DataFrame for each canonical specialty.
#     2. Prints a numeric summary of charge columns for that specialty.
#     3. Finds the top CPT codes (by frequency) and prints numeric summaries for each.
#     4. Handles missing columns or empty subsets gracefully without breaking the code.
# - Iterates through all canonical specialties to automatically generate formatted specialty- and CPT-level reports.
# - Reuses the `charge_cols` from Part B for consistent numeric analysis.

SPECIALTIES_CANON = [
    "Dermatology",
    "Ophthalmology",
    "Orthopedic",
    "Physical Medicine & Rehabilitation",
    "Psychiatry/Psychology",
    "Radiation Oncology",
]

# --- normalize specialty values in df to the canonical set above ---
import re

def _norm_key(s: str) -> str:
    """Normalize text for specialty matching: lowercase, remove spaces, replace symbols."""
    if s is None or (isinstance(s, float) and pd.isna(s)):
        return ""
    s = str(s).strip().lower()
    s = s.replace("&", "and")
    s = s.replace("/", " / ")
    s = re.sub(r"\s+", " ", s)  # collapse multiple spaces into one
    return s

# Build a lookup dictionary: normalized key -> canonical label
canon_lookup = {
    _norm_key("Dermatology"): "Dermatology",
    _norm_key("Ophthalmology"): "Ophthalmology",
    _norm_key("Orthopedic"): "Orthopedic",
    _norm_key("Physical Medicine & Rehabilitation"): "Physical Medicine & Rehabilitation",
    _norm_key("Psychiatry/Psychology"): "Psychiatry/Psychology",
    _norm_key("Radiation Oncology"): "Radiation Oncology",
}

# Create a canonical specialty column in df (non-destructive, keeps original 'specialty')
if "specialty" in df.columns:
    df["specialty_canon"] = df["specialty"].map(lambda x: canon_lookup.get(_norm_key(x), None))
else:
    df["specialty_canon"] = None  # prevents downstream errors if column is missing

# ---- Helper: build the same stats table used in Part B ----
def _make_numeric_summary(frame: pd.DataFrame, cols: list[str]) -> pd.DataFrame:
    """Create a summary table with descriptive statistics, IQR, range, and CV."""
    cols = [c for c in cols if c in frame.columns]
    if not cols:
        return pd.DataFrame()

    summary = frame[cols].agg(["count", "mean", "median", "std", "min", "max"])
    q25 = frame[cols].quantile(0.25)
    q75 = frame[cols].quantile(0.75)
    cv  = summary.loc["std"] / summary.loc["mean"]
    rng = summary.loc["max"] - summary.loc["min"]
    iqr = q75 - q25

    out = (
        pd.concat(
            {
                "count": summary.loc["count"],
                "mean": summary.loc["mean"],
                "median": summary.loc["median"],
                "std": summary.loc["std"],
                "cv_std_over_mean": cv,
                "min": summary.loc["min"],
                "q25": q25,
                "q75": q75,
                "iqr": iqr,
                "max": summary.loc["max"],
                "range_max_minus_min": rng,
            },
            axis=1,
        )
        .round(2)
    )
    return out

# ---- Main report function: Specialty- and CPT-level summaries ----
def specialty_and_cpt_report(df: pd.DataFrame, canonical_specialty: str, charge_cols: list[str],
                             cpt_list: list[str] | None = None, top_k_cpts: int = 2):
    """Generates numeric summaries for each specialty and its top CPT codes."""
    # Filter to the canonical specialty subset
    df_s = df[df.get("specialty_canon").eq(canonical_specialty)].copy()
    if df_s.empty:
        print(f"\n⚠️ No rows for specialty '{canonical_specialty}'.")
        return

    # ---- Specialty summary ----
    print("\n" + canonical_specialty.upper() + " SUMMARY")
    spec_tbl = _make_numeric_summary(df_s, charge_cols)
    print(indent(spec_tbl.to_string() if not spec_tbl.empty else "  (no numeric columns found)", "  "))

    # ---- CPT summaries ----
    if "cpt_code" not in df_s.columns:
        print("\n⚠️ No 'cpt_code' column — skipping CPT summaries.")
        return

    # If no CPT list provided, use the top-k most frequent CPTs
    if not cpt_list:
        vc = df_s["cpt_code"].value_counts(dropna=True)
        cpt_list = vc.head(max(top_k_cpts, 1)).index.tolist()

    print("\n### CPTCODE SUMMARY\n")
    print(canonical_specialty.upper())

    for cpt in cpt_list:
        df_c = df_s[df_s["cpt_code"] == cpt]
        if df_c.empty:
            continue
        print(f"\nCPT_CODE: {cpt}")
        cpt_tbl = _make_numeric_summary(df_c, charge_cols)
        print(indent(cpt_tbl.to_string(), "  "))

# ---- Run reports for all canonical specialties ----
# Reuses charge_cols from Part B and prints formatted summaries for each specialty and its top 2 CPT codes.
for spec in SPECIALTIES_CANON:
    specialty_and_cpt_report(df, canonical_specialty=spec, charge_cols=charge_cols, top_k_cpts=2)
# Out:
# DERMATOLOGY SUMMARY
#                                          count     mean   median       std  cv_std_over_mean   min      q25       q75       iqr        max  range_max_minus_min
#   standard_charge_gross             220,661.00 1,872.29   837.00  4,722.68              2.52 23.01   480.00  1,091.00    611.00  73,892.63            73,869.62
#   standard_charge_discounted_cash   220,661.00   948.85   544.05  1,813.07              1.91  5.00   232.70    676.42    443.72  17,874.25            17,869.25
#   standard_charge_negotiated_dollar 224,008.00 3,112.19 1,104.61  7,129.60              2.29  0.95   276.95  2,702.00  2,425.05 938,390.00           938,389.05
#   standard_charge_min               885,237.00 1,764.13 1,691.00  1,433.78              0.81  0.95   676.42  2,576.00  1,899.58  28,304.34            28,303.39
#   standard_charge_max               885,237.00 9,636.08 7,108.00 16,784.32              1.74  4.98 1,234.05 11,371.00 10,136.95 938,390.00           938,385.02
#
# ### CPTCODE SUMMARY
#
# DERMATOLOGY
#
# CPT_CODE: 11102
#                                          count     mean   median       std  cv_std_over_mean    min    q25       q75      iqr       max  range_max_minus_min
#   standard_charge_gross              48,323.00   993.59   966.00  1,724.91              1.74 154.00 586.00    966.00   380.00 30,057.40            29,903.40
#   standard_charge_discounted_cash    48,323.00   595.82   627.90    436.77              0.73 116.00 363.32    627.90   264.58  5,410.33             5,294.33
#   standard_charge_negotiated_dollar  37,219.00 2,118.44   492.66  5,578.34              2.63   0.95 282.60  1,816.00 1,533.40 55,609.00            55,608.05
#   standard_charge_min               122,265.00 1,544.46 1,234.00  1,553.42              1.01   0.95 272.00  2,250.00 1,978.00 11,856.87            11,855.92
#   standard_charge_max               122,265.00 7,694.03 2,867.00 10,752.76              1.40  95.58 869.40 10,268.00 9,398.60 55,609.00            55,513.42
#
# CPT_CODE: 11104
#                                          count     mean   median       std  cv_std_over_mean    min      q25       q75      iqr       max  range_max_minus_min
#   standard_charge_gross              43,698.00 1,424.55 1,091.00  2,797.42              1.96 193.00   966.00  1,091.00   125.00 42,158.73            41,965.73
#   standard_charge_discounted_cash    43,698.00   774.32   676.42    621.65              0.80 130.80   627.90    676.42    48.52  9,224.95             9,094.15
#   standard_charge_negotiated_dollar  32,252.00 2,489.00   625.97  5,779.41              2.32   0.95   393.02  2,231.00 1,837.98 97,648.00            97,647.05
#   standard_charge_min               115,597.00 1,691.76 1,495.00  1,530.51              0.90   0.95   579.00  2,361.60 1,782.60 12,404.64            12,403.69
#   standard_charge_max               115,597.00 8,183.21 3,242.00 11,194.89              1.37 119.25 1,091.00 10,268.00 9,177.00 97,648.00            97,528.75
#
# OPHTHALMOLOGY SUMMARY
#                                          count      mean   median       std  cv_std_over_mean   min      q25       q75      iqr          max  range_max_minus_min
#   standard_charge_gross              34,630.00  7,034.37   664.00  9,828.99              1.40 60.00   664.00  9,377.00 8,713.00    59,371.55            59,311.55
#   standard_charge_discounted_cash    34,630.00  3,004.58   411.68  3,709.69              1.23 12.00   411.68  5,396.63 4,984.95    19,741.31            19,729.31
#   standard_charge_negotiated_dollar  64,564.00  5,428.76 2,702.00 21,757.28              4.01  0.95 1,648.00  6,140.00 4,492.00 3,283,205.00         3,283,204.05
#   standard_charge_min               386,208.00  2,186.75 1,871.00  1,741.68              0.80  0.95   962.00  3,242.00 2,280.00    23,748.62            23,747.67
#   standard_charge_max               386,208.00 12,206.54 7,108.00 70,537.23              5.78 14.40 3,186.00 11,371.00 8,185.00 3,283,205.00         3,283,190.60
#
# ### CPTCODE SUMMARY
#
# OPHTHALMOLOGY
#
# CPT_CODE: 66984
#                                         count      mean    median        std  cv_std_over_mean      min      q25       q75       iqr          max  range_max_minus_min
#   standard_charge_gross             10,558.00 17,787.51 18,704.12   9,555.00              0.54 2,703.00 9,377.00 20,118.86 10,741.86    49,353.28            46,650.28
#   standard_charge_discounted_cash   10,558.00  6,837.10  7,481.65   3,714.48              0.54   540.60 3,750.80  7,788.62  4,037.82    19,741.31            19,200.71
#   standard_charge_negotiated_dollar 18,150.00  7,711.59  5,026.00  39,154.56              5.08     0.95 2,450.00  7,971.75  5,521.75 3,283,205.00         3,283,204.05
#   standard_charge_min               85,417.00  2,973.83  2,702.00   1,570.36              0.53     0.95 1,950.00  3,366.00  1,416.00    14,016.00            14,015.05
#   standard_charge_max               85,417.00 21,659.59 10,029.00 148,107.76              6.84   612.61 6,015.00 13,213.00  7,198.00 3,283,205.00         3,282,592.39
#
# CPT_CODE: 67028
#                                         count      mean   median       std  cv_std_over_mean    min      q25       q75      iqr       max  range_max_minus_min
#   standard_charge_gross              4,852.00  9,109.66 8,302.50  8,426.75              0.93 432.00 8,302.50  8,302.50     0.00 59,371.55            58,939.55
#   standard_charge_discounted_cash    4,852.00  5,218.02 5,396.63  1,777.15              0.34  86.40 5,396.63  5,396.63     0.00 11,874.31            11,787.91
#   standard_charge_negotiated_dollar 14,525.00  5,320.10 3,237.98  7,402.62              1.39   0.95 1,728.00  6,140.00 4,412.00 39,875.00            39,874.05
#   standard_charge_min               83,055.00  2,862.61 1,829.00  2,227.71              0.78   0.95 1,242.57  5,429.70 4,187.13 23,748.62            23,747.67
#   standard_charge_max               83,055.00 12,135.40 7,472.25 11,148.22              0.92 226.30 6,140.00 11,371.00 5,231.00 47,497.24            47,270.94
#
# ⚠️ No rows for specialty 'Orthopedic'.
#
# PHYSICAL MEDICINE & REHABILITATION SUMMARY
#                                            count   mean  median      std  cv_std_over_mean   min    q25    q75    iqr       max  range_max_minus_min
#   standard_charge_gross             1,286,553.00 343.89  274.00   242.09              0.70 23.00 233.28 379.00 145.72  3,390.00             3,367.00
#   standard_charge_discounted_cash   1,270,692.00 253.27  178.10   245.87              0.97 10.20 135.85 262.90 127.05  3,390.00             3,379.80
#   standard_charge_negotiated_dollar   680,136.00 227.75  104.12   940.95              4.13  0.95  34.82 184.71 149.89 36,828.00            36,827.05
#   standard_charge_min               1,364,903.00  76.37   34.20    78.11              1.02  0.95  22.70 114.70  92.00    661.28               660.33
#   standard_charge_max               1,380,099.00 376.53  210.60 1,051.71              2.79  9.62  95.00 305.00 210.00 36,828.00            36,818.38
#
# ### CPTCODE SUMMARY
#
# PHYSICAL MEDICINE & REHABILITATION
#
# CPT_CODE: 97530
#                                          count   mean  median    std  cv_std_over_mean   min    q25    q75    iqr       max  range_max_minus_min
#   standard_charge_gross             199,667.00 243.87  234.00 105.18              0.43 24.00 185.00 234.00  49.00  1,203.00             1,179.00
#   standard_charge_discounted_cash   197,583.00 173.09  152.10 123.83              0.72 12.00 114.70 152.10  37.40  1,203.00             1,191.00
#   standard_charge_negotiated_dollar 118,774.00 186.13   89.00 792.84              4.26  0.95  38.05 152.10 114.05 17,911.00            17,910.05
#   standard_charge_min               208,311.00  54.10   30.15  52.49              0.97  0.95  22.70  87.00  64.30    550.00               549.05
#   standard_charge_max               210,325.00 344.95  206.40 900.41              2.61 24.00 143.22 210.60  67.38 15,779.00            15,755.00
#
# CPT_CODE: 97110
#                                          count   mean  median    std  cv_std_over_mean   min    q25    q75    iqr       max  range_max_minus_min
#   standard_charge_gross             178,318.00 277.72  234.00 147.28              0.53 47.55 230.29 257.00  26.71  1,261.00             1,213.45
#   standard_charge_discounted_cash   176,247.00 200.39  152.10 167.48              0.84 22.60 152.10 159.34   7.24  1,261.00             1,238.40
#   standard_charge_negotiated_dollar 109,691.00 166.16   90.32 760.52              4.58  0.95  31.48 160.93 129.45 17,911.00            17,910.05
#   standard_charge_min               187,590.00  55.92   24.32  64.45              1.15  0.95  22.70  60.48  37.78    550.00               549.05
#   standard_charge_max               189,556.00 321.87  210.60 839.62              2.61 20.03  97.28 257.00 159.72 16,075.00            16,054.97
#
# PSYCHIATRY/PSYCHOLOGY SUMMARY
#                                          count   mean  median      std  cv_std_over_mean   min    q25    q75    iqr        max  range_max_minus_min
#   standard_charge_gross             709,836.00 452.38  376.65   236.16              0.52 30.00 339.00 497.00 158.00   2,299.00             2,269.00
#   standard_charge_discounted_cash   685,087.00 294.24  257.30   170.75              0.58 19.80 210.18 327.60 117.42   2,299.00             2,279.20
#   standard_charge_negotiated_dollar  92,642.00 623.67  231.77 2,199.34              3.53  0.95 151.17 396.00 244.83 144,811.00           144,810.05
#   standard_charge_min               745,144.00 219.98  210.18   102.04              0.46  0.95 200.26 257.30  57.04   1,236.00             1,235.05
#   standard_charge_max               769,140.00 675.52  339.00 4,964.74              7.35 28.80 323.00 427.00 104.00 144,811.00           144,782.20
#
# ### CPTCODE SUMMARY
#
# PSYCHIATRY/PSYCHOLOGY
#
# CPT_CODE: 90853
#                                          count   mean  median      std  cv_std_over_mean   min    q25    q75    iqr       max  range_max_minus_min
#   standard_charge_gross             281,506.00 347.42  339.00   102.31              0.29 30.00 339.00 339.00   0.00  2,299.00             2,269.00
#   standard_charge_discounted_cash   270,124.00 229.93  210.18   102.27              0.44 19.80 210.18 210.18   0.00  2,299.00             2,279.20
#   standard_charge_negotiated_dollar  24,439.00 683.12  231.77 1,935.84              2.83  0.95  91.00 278.00 187.00 81,319.00            81,318.05
#   standard_charge_min               270,722.00 189.12  210.18    59.13              0.31  0.95 210.18 210.18   0.00    694.00               693.05
#   standard_charge_max               282,022.00 445.03  339.00 1,911.10              4.29 28.80 339.00 339.00   0.00 81,319.00            81,290.20
#
# CPT_CODE: 90847
#                                          count   mean  median      std  cv_std_over_mean   min    q25    q75    iqr        max  range_max_minus_min
#   standard_charge_gross             102,051.00 497.23  415.00   257.81              0.52 86.16 415.00 415.00   0.00   2,176.80             2,090.64
#   standard_charge_discounted_cash    99,219.00 342.04  257.30   212.79              0.62 78.80 257.30 304.47  47.17   1,432.08             1,353.28
#   standard_charge_negotiated_dollar  10,949.00 703.77  236.50 2,466.44              3.50  0.95 156.44 553.00 396.56 144,811.00           144,810.05
#   standard_charge_min                98,557.00 235.62  257.30    97.89              0.42  0.95 228.00 257.30  29.30   1,236.00             1,235.05
#   standard_charge_max               101,331.00 693.66  415.00 5,396.21              7.78 74.76 415.00 415.00   0.00 144,811.00           144,736.24
#
# RADIATION ONCOLOGY SUMMARY
#                                          count     mean   median       std  cv_std_over_mean    min      q25      q75      iqr          max  range_max_minus_min
#   standard_charge_gross             297,493.00 7,184.07 6,295.00  6,763.19              0.94 223.00 2,582.85 8,528.00 5,945.15    68,762.25            68,539.25
#   standard_charge_discounted_cash   296,681.00 4,464.52 3,902.90  4,493.25              1.01  87.80 1,421.82 5,543.20 4,121.38    68,762.25            68,674.45
#   standard_charge_negotiated_dollar 128,609.00 4,142.47 1,533.60 13,146.68              3.17   0.95   720.00 3,739.00 3,019.00 1,169,274.00         1,169,273.05
#   standard_charge_min               372,362.00 2,955.26 1,669.15  3,504.27              1.19   0.01   666.00 4,259.40 3,593.40    41,970.00            41,969.99
#   standard_charge_max               373,174.00 8,399.63 5,671.00 35,230.61              4.19   0.01 1,838.70 7,675.20 5,836.50 1,169,274.00         1,169,273.99
#
# ### CPTCODE SUMMARY
#
# RADIATION ONCOLOGY
#
# CPT_CODE: 77334
#                                         count     mean   median       std  cv_std_over_mean    min      q25      q75      iqr        max  range_max_minus_min
#   standard_charge_gross             55,336.00 2,460.57 2,043.00    760.42              0.31 237.64 2,043.00 3,013.00   970.00   5,386.00             5,148.36
#   standard_charge_discounted_cash   55,336.00 1,559.82 1,327.95    571.64              0.37  93.80 1,327.95 1,868.06   540.11   5,363.00             5,269.20
#   standard_charge_negotiated_dollar 33,079.00 1,691.11   889.00  8,199.91              4.85   0.95   379.26 1,398.00 1,018.74 259,042.00           259,041.05
#   standard_charge_min               60,638.00 1,236.04   114.12  1,899.70              1.54   0.01   114.12 1,868.06 1,753.94  13,000.00            12,999.99
#   standard_charge_max               60,638.00 3,434.15 1,838.70 12,628.55              3.68   0.01 1,838.70 3,013.00 1,174.30 259,042.00           259,041.99
#
# CPT_CODE: 77014
#                                         count     mean   median      std  cv_std_over_mean    min      q25      q75      iqr        max  range_max_minus_min
#   standard_charge_gross             38,060.00 2,227.57 1,126.00 2,259.79              1.01 439.00 1,121.00 2,339.14 1,218.14  18,188.77            17,749.77
#   standard_charge_discounted_cash   38,060.00 1,623.16   940.35 2,222.54              1.37  87.80   695.02 1,774.80 1,079.78  18,188.77            18,100.97
#   standard_charge_negotiated_dollar 14,031.00 1,080.15   816.00 2,353.59              2.18   0.95   365.01 1,394.50 1,029.49 170,923.00           170,922.05
#   standard_charge_min               51,492.00   687.11   695.02   454.73              0.66   0.01   415.00   852.00   437.00   2,026.00             2,025.99
#   standard_charge_max               51,492.00 2,104.01 1,428.30 8,859.05              4.21   0.01 1,121.00 1,766.00   645.00 170,923.00           170,922.99

# %%
# ---- 2) Extremes: top/bottom negotiated records with context -------------------------
print("\n" + "-"*100)
print("B4) EXTREMES: Highest and Lowest negotiated prices with hospital/payer/CPT context")
print("-"*100)

# Choose context columns that exist to display along with top/bottom price records
context_cols = [c for c in ["hospital_name", "payer_name", "plan_name", "cpt_code", "bucket", "setting", "specialty"] if c in df.columns]

def show_extremes(col, k=5):
    """
    Print the top-k and bottom-k rows by the given numeric column `col`,
    including helpful context columns (hospital, payer, plan, CPT, etc.).
    Skips gracefully if the column is missing or has no non-null values.
    """
    if col not in df.columns:
        print(f"• Skipped {col}: not in dataframe.")
        return
    # Drop NA values in the target column so the ranking is meaningful
    sub = df[context_cols + [col]].dropna(subset=[col])
    if sub.empty:
        print(f"• Skipped {col}: no non-null values.")
        return

    # Show highest k values
    print(f"\n→ TOP {k} by '{col}':")
    topk = sub.nlargest(k, col)
    print(indent(topk.to_string(index=False), "  "))

    # Show lowest k values
    print(f"\n→ BOTTOM {k} by '{col}':")
    botk = sub.nsmallest(k, col)
    print(indent(botk.to_string(index=False), "  "))

# Show extremes for negotiated dollar first (most decision-relevant)
if neg in df.columns:
    show_extremes(neg, k=5)
# Optionally also for discounted cash and gross
if cash in df.columns:
    show_extremes(cash, k=5)
if g in df.columns:
    show_extremes(g, k=5)

# ---- 4) (Optional) Quick view by payer bucket ----------------------------------------
print("\n" + "-"*100)
print("B5) QUICK BY-BUCKET SUMMARY (Commercial vs Government vs Self-Pay)")
print("-"*100)

if "bucket" in df.columns:
    # Build aggregation map for the available charge columns; use medians for robustness to outliers
    agg_map = {}
    if g in df:    agg_map[g] = "median"
    if cash in df: agg_map[cash] = "median"
    if neg in df:  agg_map[neg] = "median"

    if agg_map:
        # Group by payer bucket; compute median charges + row counts; sort by the first metric for readability
        bucket_summary = (
            df.groupby("bucket")
              .agg({**agg_map, **{"cpt_code": "count"}})
              .rename(columns={"cpt_code": "row_count"})
              .sort_values(by=list(agg_map.keys())[0], ascending=False)
              .round(2)
        )
        print("→ Median charges by bucket (+ row counts):")
        print(indent(bucket_summary.to_string(), "  "))

        # Also show median discount percentages by bucket if those columns were computed elsewhere
        disc_cols = [c for c in ["discount_cash_pct", "discount_negotiated_pct"] if c in df.columns]
        if disc_cols:
            bucket_discounts = df.groupby("bucket")[disc_cols].median().round(2)
            print("\n→ Median discount % by bucket:")
            print(indent(bucket_discounts.to_string(), "  "))
    else:
        print("• Skipped: no charge columns available to aggregate.")
else:
    print("• Skipped: 'bucket' column not found.")

# Final checkpoint message for Part B
print("\n✅ Part B complete — produced interpretable metrics .")
# Out:
# ----------------------------------------------------------------------------------------------------
# B4) EXTREMES: Highest and Lowest negotiated prices with hospital/payer/CPT context
# ----------------------------------------------------------------------------------------------------
#
# → TOP 5 by 'standard_charge_negotiated_dollar':
#                 hospital_name                          payer_name   plan_name cpt_code     bucket    setting          specialty  standard_charge_negotiated_dollar
#   AdventHealth North Pinellas blue_cross_&_blue_shield_of_florida traditional    29827 Commercial outpatient Orthopedic Surgery                       9,593,845.00
#   AdventHealth North Pinellas blue_cross_&_blue_shield_of_florida traditional    29827 Commercial outpatient Orthopedic Surgery                       9,593,845.00
#   AdventHealth North Pinellas blue_cross_&_blue_shield_of_florida traditional    33249 Commercial outpatient         Cardiology                       8,776,837.00
#   AdventHealth North Pinellas blue_cross_&_blue_shield_of_florida traditional    33249 Commercial outpatient         Cardiology                       8,776,837.00
#   AdventHealth North Pinellas blue_cross_&_blue_shield_of_florida traditional    93580 Commercial outpatient         Cardiology                       8,132,177.00
#
# → BOTTOM 5 by 'standard_charge_negotiated_dollar':
#           hospital_name        payer_name                                         plan_name cpt_code     bucket    setting                          specialty  standard_charge_negotiated_dollar
#   Delray Medical Center molina healthcare of texas (claims only) molinacompletecaremgdmcaid    97110 Government outpatient Physical Medicine & Rehabilitation                               0.95
#   Delray Medical Center molina healthcare of texas (claims only) molinacompletecaremgdmcaid    27130 Government outpatient                 Orthopedic Surgery                               0.95
#   Delray Medical Center molina healthcare of texas (claims only) molinacompletecaremgdmcaid    39503 Government outpatient                  Pediatric Surgery                               0.95
#   Delray Medical Center molina healthcare of texas (claims only) molinacompletecaremgdmcaid    93306 Government outpatient                         Cardiology                               0.95
#   Delray Medical Center molina healthcare of texas (claims only) molinacompletecaremgdmcaid    64721 Government outpatient                       Neurosurgery                               0.95
#
# → TOP 5 by 'standard_charge_discounted_cash':
#   hospital_name          payer_name                                     plan_name cpt_code     bucket    setting  specialty  standard_charge_discounted_cash
#     HSA FMC LLC aetna better health medicaid hmo aetna better health medicaid hmo    33249 Government outpatient Cardiology                       213,209.45
#    HSA NSMC LLC aetna better health medicaid hmo aetna better health medicaid hmo    33249 Government outpatient Cardiology                       213,209.45
#     HSA FMC LLC               aetna                       exchange aetna exchange    33249 Commercial outpatient Cardiology                       213,209.45
#    HSA NSMC LLC               aetna                       exchange aetna exchange    33249 Commercial outpatient Cardiology                       213,209.45
#     HSA FMC LLC               aetna                   gatekeeper aetna gatekeeper    33249 Commercial outpatient Cardiology                       213,209.45
#
# → BOTTOM 5 by 'standard_charge_discounted_cash':
#               hospital_name     payer_name            plan_name cpt_code     bucket    setting          specialty  standard_charge_discounted_cash
#              REHAB HOSPITAL AETNA [210101] AETNA PPO [21010105]    36556 Commercial outpatient Emergency Medicine                             0.20
#              REHAB HOSPITAL AETNA [210101] AETNA PPO [21010105]    20605 Commercial outpatient Orthopedic Surgery                             0.20
#              REHAB HOSPITAL AETNA [210101] AETNA PPO [21010105]    20610 Commercial outpatient Orthopedic Surgery                             0.20
#              REHAB HOSPITAL AETNA [210101] AETNA PPO [21010105]    20600 Commercial outpatient Orthopedic Surgery                             0.20
#   HEALTHPARK MEDICAL CENTER AETNA [210101] AETNA PPO [21010105]    36556 Commercial outpatient Emergency Medicine                             0.20
#
# → TOP 5 by 'standard_charge_gross':
#                                 hospital_name payer_name                              plan_name cpt_code     bucket    setting    specialty  standard_charge_gross
#   Physicians Regional Med Center - Pine Ridge      Aetna                                  Aetna    22630 Commercial outpatient Neurosurgery             400,176.50
#   Physicians Regional Med Center - Pine Ridge      Aetna                              Aetna ASA    22630 Commercial outpatient Neurosurgery             400,176.50
#   Physicians Regional Med Center - Pine Ridge      Aetna                     Aetna First Health    22630 Commercial outpatient Neurosurgery             400,176.50
#   Physicians Regional Med Center - Pine Ridge      Aetna                    Aetna INTL Passport    22630 Commercial outpatient Neurosurgery             400,176.50
#   Physicians Regional Med Center - Pine Ridge       NODE Wellcare MCR ADV NODE Wellcare MCR ADV    22630 Government outpatient Neurosurgery             400,176.50
#
# → BOTTOM 5 by 'standard_charge_gross':
#               hospital_name     payer_name            plan_name cpt_code     bucket    setting          specialty  standard_charge_gross
#              REHAB HOSPITAL AETNA [210101] AETNA PPO [21010105]    36556 Commercial outpatient Emergency Medicine                   1.00
#              REHAB HOSPITAL AETNA [210101] AETNA PPO [21010105]    20605 Commercial outpatient Orthopedic Surgery                   1.00
#              REHAB HOSPITAL AETNA [210101] AETNA PPO [21010105]    20610 Commercial outpatient Orthopedic Surgery                   1.00
#              REHAB HOSPITAL AETNA [210101] AETNA PPO [21010105]    20600 Commercial outpatient Orthopedic Surgery                   1.00
#   HEALTHPARK MEDICAL CENTER AETNA [210101] AETNA PPO [21010105]    36556 Commercial outpatient Emergency Medicine                   1.00
#
# ----------------------------------------------------------------------------------------------------
# B5) QUICK BY-BUCKET SUMMARY (Commercial vs Government vs Self-Pay)
# ----------------------------------------------------------------------------------------------------
# → Median charges by bucket (+ row counts):
#               standard_charge_gross  standard_charge_discounted_cash  standard_charge_negotiated_dollar  row_count
#   bucket
#   Self Pay                 1,398.33                         1,284.02                             357.16      19349
#   Government                 966.00                           695.02                             356.78    4451512
#   Unknown                    945.00                           607.60                           7,214.00     498844
#   Commercial                 909.06                           585.90                           1,728.00    5240259
#
# ✅ Part B complete — produced interpretable metrics .

# %% [markdown]
# ---
#
# ## 📊 **Part C: Data Summary**
#
# **Goal:** Summarize key dataset composition and pricing metrics.
#
# - **Number of hospitals**
# - **Number of payers** *(Commercial / Government / Self-pay)*
# - **Mean & median prices by CPT codes**
# - **Distinct payer counts per bucket**
#
# ---

# %%
# ======================================= PART C — DATA SUMMARY =======================================
# ✅ In summary, this section:
# - Prints a header for Part C.
# - Sets column-name variables used throughout the summary.
# - Reports the number of unique hospitals (if the column exists).
# - Computes CPT-level mean/median (and count) for key price columns, with readable column names.
# - Normalizes payer bucket labels (Commercial / Government / Self Pay / Unknown).
# - Counts DISTINCT payers per normalized bucket and prints a sorted table.
# - Builds a roster preview (unique payer names) per bucket.
# - Prints a completion message when Part C finishes.

print("\n" + "="*100)
print("PART C — DATA SUMMARY")
print("="*100)

# ---- Column references ----
# Keep all column names in one place to avoid typos and enable easy refactoring.
col_hosp = "hospital_name"
col_bucket = "bucket"
col_payer = "payer_name"
col_cpt = "cpt_code"
col_gross = "standard_charge_gross"
col_cash = "standard_charge_discounted_cash"
col_neg = "standard_charge_negotiated_dollar"
col_final_rate = "standard_charge_max"

# =============================  Number of hospitals =============================
# If the hospital column is present, print the number of distinct (non-null) hospitals represented.
if col_hosp in df.columns:
    n_hospitals = df[col_hosp].nunique(dropna=True)
    print(f"\n→ Total unique hospitals represented: {n_hospitals:,}")
else:
    # Graceful skip if the expected column is not available.
    print("\n⚠️ 'hospital_name' column not found — skipping hospital count.")

# =============================  CPT-level mean & median prices =============================
print("\n" + "-"*100)
print("D3) Mean & Median Prices by CPT Code")
print("-"*100)

# Choose the price columns we care about, but only keep those that actually exist in the dataframe.
price_cols = [col_gross, col_cash, col_neg, col_final_rate]
existing_price_cols = [c for c in price_cols if c in df.columns]

if col_cpt in df.columns and existing_price_cols:
    # Compute aggregate metrics per CPT code: mean, median, and count for each available price column.
    cpt_summary = (
        df.groupby(col_cpt)[existing_price_cols]
          .agg(["mean", "median", "count"])
          .round(2)
    )

    # Flatten the MultiIndex columns (e.g., ('standard_charge_gross','mean') -> 'standard_charge_gross_mean')
    cpt_summary.columns = ['_'.join(col).strip() for col in cpt_summary.columns.values]
    cpt_summary = cpt_summary.reset_index()

    # Show only the first 10 rows for readability.
    print("→ CPT-level summary (showing top 10 rows):")
    print(indent(cpt_summary.head(10).to_string(index=False), "  "))

# ==================== DISTINCT PAYERS BY BUCKET  ====================

from textwrap import indent  # used only for pretty printing/indenting tables

COL_BUCKET = "bucket"
COL_PAYER  = "payer_name"

# --- 0) Normalize bucket labels so similar terms collapse properly ---
# Map many possible raw labels into a small set of canonical categories.
bucket_map = {
    "commercial": "Commercial",
    "comm": "Commercial",
    "gov": "Government",
    "government": "Government",
    "medicare": "Government",
    "medicaid": "Government",
    "self pay": "Self Pay",
    "self-pay": "Self Pay",
    "selfpay": "Self Pay",
    "cash": "Self Pay",
}
def normalize_bucket(s):
    """
    Convert raw bucket values to canonical labels:
    - Handle NaN -> 'Unknown'
    - Lowercase/strip input for matching
    - Collapse variants like 'comm' or 'self-pay'
    - Preserve already-canonical labels; otherwise -> 'Unknown'
    """
    if pd.isna(s):
        return "Unknown"
    key = str(s).strip().lower()
    return bucket_map.get(key, s if s in ["Commercial", "Government", "Self Pay"] else "Unknown")

# Create a normalized bucket column so grouping is consistent and robust to messy input.
df["_bucket_norm"] = df[COL_BUCKET].apply(normalize_bucket)

# --- 1️⃣ DISTINCT payer counts per bucket ---
# For each normalized bucket, count how many UNIQUE payer names appear.
# Result is a small table sorted by the number of unique payers (descending).
payers_by_bucket = (
    df.dropna(subset=[COL_PAYER])
      .groupby("_bucket_norm")[COL_PAYER]
      .nunique()
      .reset_index(name="unique_payers")
      .sort_values("unique_payers", ascending=False)
)

print("\n→ DISTINCT payers by bucket:")
print(indent(payers_by_bucket.to_string(index=False), "  "))

# --- 2️⃣ Roster preview: show first 10 payer names per bucket ---
# Build a roster table: for each normalized bucket, list the unique payer names (sorted).
# Note: this gathers the full list; you can `.str[:10]` or similar later if you want to preview fewer.
roster = (
    df.dropna(subset=[COL_PAYER])
      .groupby("_bucket_norm")[COL_PAYER]
      .apply(lambda s: sorted(s.dropna().unique().tolist()))
      .reset_index(name="payer_list")
)

# Final status line for Part C to mark completion of the summary step.
print("\n✅ Part C complete.")
# Out:
# ====================================================================================================
# PART C — DATA SUMMARY
# ====================================================================================================
#
# → Total unique hospitals represented: 157
#
# ----------------------------------------------------------------------------------------------------
# D3) Mean & Median Prices by CPT Code
# ----------------------------------------------------------------------------------------------------
# → CPT-level summary (showing top 10 rows):
#   cpt_code  standard_charge_gross_mean  standard_charge_gross_median  standard_charge_gross_count  standard_charge_discounted_cash_mean  standard_charge_discounted_cash_median  standard_charge_discounted_cash_count  standard_charge_negotiated_dollar_mean  standard_charge_negotiated_dollar_median  standard_charge_negotiated_dollar_count  standard_charge_max_mean  standard_charge_max_median  standard_charge_max_count
#      10040                    1,138.79                        589.00                         4447                                388.85                                  235.60                                   4447                                4,419.76                                  2,145.00                                    13626                 11,277.80                    7,108.00                      77748
#      11102                      993.59                        966.00                        48323                                595.82                                  627.90                                  48323                                2,118.44                                    492.66                                    37219                  7,694.03                    2,867.00                     122265
#      11104                    1,424.55                      1,091.00                        43698                                774.32                                  676.42                                  43698                                2,489.00                                    625.97                                    32252                  8,183.21                    3,242.00                     115597
#      11900                      709.11                        358.00                        31474                                346.82                                  232.70                                  31474                                3,094.32                                    664.00                                    25242                  8,958.60                    6,174.00                     103973
#      12002                    1,653.07                      1,935.00                        50232                                944.38                                1,199.70                                  50232                                2,962.02                                    538.00                                    27589                  7,757.20                    2,702.00                     123135
#      14040                    9,757.16                      7,704.00                        20604                              4,963.54                                4,841.20                                  20604                                5,041.20                                  3,067.00                                    26269                 13,014.29                    7,108.00                      94428
#      15781                    2,969.26                      3,010.00                         1729                              1,824.76                                1,956.50                                   1729                                5,171.43                                  2,702.00                                    12712                 12,066.87                    8,503.00                      75076
#      17000                    1,042.91                        485.00                        12449                                392.88                                  250.00                                  12449                                3,193.06                                  1,326.00                                    19441                 10,674.67                    7,108.00                      83728
#      17003                      469.15                         85.00                        11385                                120.98                                   50.70                                  11385                                3,490.12                                  1,495.00                                    16399                 10,397.93                    7,108.00                      81932
#      17110                    1,333.34                        837.00                        37203                                579.85                                  463.76                                  37203                                2,655.16                                    513.08                                    30646                  8,613.55                    5,498.00                     110469
#
# → DISTINCT payers by bucket:
#   _bucket_norm  unique_payers
#     Commercial            542
#     Government            419
#        Unknown            114
#       Self Pay              9
#
# ✅ Part C complete.

# %% [markdown]
# ---
#
# ## 📊 **Part C+: Summaries**
#
# **Goal:** Generate numeric summaries at three levels:
# - **Overall** dataset
# - **By payer bucket** (Commercial, Government, Self Pay)
# - **Top 2 CPT codes** per bucket
#
# Includes stats for count, mean, median, std, CV, range, and IQR.
#
# ---

# %%
# ========================= PART C+: SUMMARIES (OVERALL, BY BUCKET, CPT IN BUCKET) =========================
# ✅ In summary:
# - Pick the active dataframe (cap-limited if available), else fall back to the full df.
# - Detect which charge columns exist and will be summarized.
# - Use a reusable function to compute descriptive stats + IQR, range, CV.
# - Print: (1) Overall summary, (2) By-bucket summaries, (3) CPT-by-bucket (top 2 CPTs per bucket).
# - Handle missing columns or empty subsets gracefully.

# pick the working frame (use capped if present)
_ddd = df_cap if 'df_cap' in globals() else df

# choose numeric charge columns that exist
_charge_candidates = [
    "standard_charge_gross",
    "standard_charge_discounted_cash",
    "standard_charge_negotiated_dollar",
    "standard_charge_min",
    "standard_charge_max",
    "Rate_using_min",
    "Rate_using_max",
]
_charge_cols = [c for c in _charge_candidates if c in _ddd.columns]

def _make_numeric_summary(frame: pd.DataFrame, cols: list[str]) -> pd.DataFrame:
    """
    Build a numeric summary table for the provided columns:
      - count, mean, median, std, min, max
      - q25, q75, IQR (q75 - q25)
      - range (max - min)
      - CV (std / mean)
    Returns an empty DataFrame if no valid columns or the frame is empty.
    """
    cols = [c for c in cols if c in frame.columns]
    if not cols or frame.empty:
        return pd.DataFrame()
    summary = frame[cols].agg(["count", "mean", "median", "std", "min", "max"])
    q25 = frame[cols].quantile(0.25)
    q75 = frame[cols].quantile(0.75)
    cv  = summary.loc["std"] / summary.loc["mean"]
    rng = summary.loc["max"] - summary.loc["min"]
    iqr = q75 - q25
    out = (
        pd.concat(
            {
                "count": summary.loc["count"],
                "mean": summary.loc["mean"],
                "median": summary.loc["median"],
                "std": summary.loc["std"],
                "cv_std_over_mean": cv,
                "min": summary.loc["min"],
                "q25": q25,
                "q75": q75,
                "iqr": iqr,
                "max": summary.loc["max"],
                "range_max_minus_min": rng,
            },
            axis=1,
        ).round(2)
    )
    return out

# ---------- 1) OVERALL SUMMARY ----------
print("\nOVERALL SUMMARY")
overall_tbl = _make_numeric_summary(_ddd, _charge_cols)
print(indent(overall_tbl.to_string() if not overall_tbl.empty else "  (no numeric columns found)", "  "))

# ---------- 2) BY BUCKET SUMMARY (uses your normalized column if present) ----------
# Prefer normalized bucket labels if available; otherwise use raw 'bucket'
bucket_col = "_bucket_norm" if "_bucket_norm" in _ddd.columns else "bucket"
if bucket_col in _ddd.columns:
    for b in _ddd[bucket_col].dropna().unique():
        sub = _ddd[_ddd[bucket_col] == b]
        print(f"\n{str(b).upper()} SUMMARY")
        b_tbl = _make_numeric_summary(sub, _charge_cols)
        print(indent(b_tbl.to_string() if not b_tbl.empty else "  (no data for this bucket)", "  "))
else:
    print("\n⚠️ No bucket column present for by-bucket summaries.")

# ---------- 3) CPTCODE SUMMARY BY BUCKET (top 2 CPTs per bucket by volume) ----------
# For each bucket, pick the two most frequent CPT codes and show summaries for them.
if bucket_col in _ddd.columns and "cpt_code" in _ddd.columns:
    print("\n### CPTCODE SUMMARY BY BUCKET")
    for b in _ddd[bucket_col].dropna().unique():
        sub = _ddd[_ddd[bucket_col] == b]
        # pick top 2 CPTs by count to keep output readable (adjust as needed)
        top_cpts = sub["cpt_code"].value_counts(dropna=True).head(2).index.tolist()
        if not top_cpts:
            continue
        print(f"\n{str(b).upper()}")
        for cpt in top_cpts:
            sub_cpt = sub[sub["cpt_code"] == cpt]
            print(f"\nCPT_CODE: {cpt}")
            cpt_tbl = _make_numeric_summary(sub_cpt, _charge_cols)
            print(indent(cpt_tbl.to_string() if not cpt_tbl.empty else "  (no numeric columns for this CPT)", "  "))
else:
    print("\n⚠️ Missing bucket or cpt_code column — skipping CPT-by-bucket summaries.")
# Out:
# OVERALL SUMMARY
#                                            count      mean   median       std  cv_std_over_mean  min    q25       q75       iqr          max  range_max_minus_min
#   standard_charge_gross             4,508,970.00  6,800.75   944.40 16,951.12              2.49 1.00 339.00  4,400.00  4,061.00   400,176.50           400,175.50
#   standard_charge_discounted_cash   4,452,892.00  4,472.06   624.75 12,045.57              2.69 0.20 210.18  2,773.26  2,563.08   213,209.45           213,209.25
#   standard_charge_negotiated_dollar 2,675,650.00  5,352.60 1,301.88 21,680.36              4.05 0.95 198.90  5,831.00  5,632.10 9,593,845.00         9,593,844.05
#   standard_charge_min               9,668,019.00  3,141.49 1,728.00  5,321.91              1.69 0.01 213.83  3,375.90  3,162.07   108,919.00           108,918.99
#   standard_charge_max               9,721,835.00 13,214.15 5,769.56 86,019.59              6.51 0.01 677.00 14,540.00 13,863.00 9,593,845.00         9,593,844.99
#
# COMMERCIAL SUMMARY
#                                            count      mean   median       std  cv_std_over_mean  min    q25       q75       iqr          max  range_max_minus_min
#   standard_charge_gross             2,886,810.00  6,497.51   909.06 15,995.65              2.46 1.00 339.00  4,243.77  3,904.77   400,176.50           400,175.50
#   standard_charge_discounted_cash   2,865,900.00  4,187.48   585.90 11,024.04              2.63 0.20 210.18  2,666.00  2,455.82   213,209.45           213,209.25
#   standard_charge_negotiated_dollar 1,699,238.00  6,405.85 1,728.00 26,508.99              4.14 1.00 246.60  7,265.00  7,018.40 9,593,845.00         9,593,844.00
#   standard_charge_min               4,986,908.00  2,909.90 1,439.00  5,626.16              1.93 0.01 210.18  3,242.00  3,031.82   108,919.00           108,918.99
#   standard_charge_max               5,006,956.00 12,260.19 3,500.00 84,838.31              6.92 0.01 454.53 12,077.00 11,622.47 9,593,845.00         9,593,844.99
#
# GOVERNMENT SUMMARY
#                                            count      mean   median       std  cv_std_over_mean  min      q25       q75       iqr          max  range_max_minus_min
#   standard_charge_gross             1,447,288.00  7,372.75   966.00 18,600.42              2.52 1.00   339.00  4,685.82  4,346.82   400,176.50           400,175.50
#   standard_charge_discounted_cash   1,412,668.00  5,016.94   695.02 13,690.62              2.73 0.20   216.75  3,409.90  3,193.15   213,209.45           213,209.25
#   standard_charge_negotiated_dollar   842,419.00  2,373.45   356.78  5,775.43              2.43 0.95    67.38  2,250.00  2,182.62   213,209.45           213,208.50
#   standard_charge_min               4,190,841.00  3,382.41 1,950.00  4,959.68              1.47 0.01   340.00  4,072.00  3,732.00   106,604.73           106,604.72
#   standard_charge_max               4,224,061.00 14,109.80 7,108.00 88,066.76              6.24 0.01 1,203.12 15,017.75 13,814.63 9,593,845.00         9,593,844.99
#
# UNKNOWN SUMMARY
#                                          count      mean   median       std  cv_std_over_mean   min      q25       q75       iqr          max  range_max_minus_min
#   standard_charge_gross             155,523.00  7,019.43   945.00 17,520.91              2.50 30.10   339.00  4,473.00  4,134.00   400,176.50           400,146.40
#   standard_charge_discounted_cash   154,975.00  4,580.90   607.60 13,402.08              2.93 12.04   220.85  2,728.00  2,507.15   213,209.45           213,197.41
#   standard_charge_negotiated_dollar 125,049.00 11,233.86 7,214.00 12,856.90              1.14  7.25 2,421.00 16,049.00 13,628.00   213,209.45           213,202.20
#   standard_charge_min               471,730.00  3,523.12 2,250.00  5,032.17              1.43  0.01   712.00  4,486.20  3,774.20   106,604.73           106,604.72
#   standard_charge_max               472,278.00 15,563.26 7,108.00 81,194.91              5.22  0.01 1,995.00 21,936.00 19,941.00 9,593,845.00         9,593,844.99
#
# SELF PAY SUMMARY
#                                         count     mean   median       std  cv_std_over_mean   min    q25      q75      iqr          max  range_max_minus_min
#   standard_charge_gross             19,349.00 7,500.51 1,398.33 20,032.20              2.67 31.24 556.99 3,816.09 3,259.10   400,176.50           400,145.26
#   standard_charge_discounted_cash   19,349.00 5,968.68 1,284.02 15,236.26              2.55 12.50 425.10 3,200.00 2,774.90   213,209.45           213,196.95
#   standard_charge_negotiated_dollar  8,944.00 3,622.78   357.16 10,959.90              3.03 13.52 132.71 1,785.47 1,652.76   213,209.45           213,195.93
#   standard_charge_min               18,540.00 1,263.47   229.78  3,972.43              3.14  3.58 104.58   648.31   543.73   106,604.73           106,601.15
#   standard_charge_max               18,540.00 6,942.36 1,130.70 25,551.25              3.68 17.68 336.15 4,620.96 4,284.81 2,222,478.66         2,222,460.98
#
# ### CPTCODE SUMMARY BY BUCKET
#
# COMMERCIAL
#
# CPT_CODE: 90853
#                                          count   mean  median      std  cv_std_over_mean   min    q25    q75    iqr       max  range_max_minus_min
#   standard_charge_gross             195,173.00 343.99  339.00    81.77              0.24 30.00 339.00 339.00   0.00  2,299.00             2,269.00
#   standard_charge_discounted_cash   193,721.00 223.38  210.18    78.47              0.35 19.80 210.18 210.18   0.00  2,299.00             2,279.20
#   standard_charge_negotiated_dollar  11,667.00 965.68  207.50 2,606.97              2.70  6.35  90.99 380.00 289.01 81,319.00            81,312.65
#   standard_charge_min               192,896.00 194.91  210.18    51.48              0.26  0.95 210.18 210.18   0.00    694.00               693.05
#   standard_charge_max               194,330.00 420.02  339.00 1,633.72              3.89 28.80 339.00 339.00   0.00 81,319.00            81,290.20
#
# CPT_CODE: 97530
#                                          count   mean  median    std  cv_std_over_mean   min    q25    q75   iqr       max  range_max_minus_min
#   standard_charge_gross             130,588.00 236.89  234.00  96.13              0.41 24.00 185.00 234.00 49.00  1,203.00             1,179.00
#   standard_charge_discounted_cash   129,806.00 163.68  152.10 111.10              0.68 12.00 114.70 152.10 37.40  1,203.00             1,191.00
#   standard_charge_negotiated_dollar  76,528.00 230.60  125.00 933.27              4.05  5.43  88.92 187.20 98.28 17,911.00            17,905.57
#   standard_charge_min               129,817.00  55.15   22.70  53.33              0.97  0.95  22.70 114.70 92.00    550.00               549.05
#   standard_charge_max               130,579.00 342.73  210.60 859.81              2.51 24.00 185.00 210.60 25.60 15,779.00            15,755.00
#
# GOVERNMENT
#
# CPT_CODE: 97530
#                                         count   mean  median    std  cv_std_over_mean   min    q25    q75    iqr       max  range_max_minus_min
#   standard_charge_gross             63,652.00 256.05  234.00 116.14              0.45 24.00 185.00 255.25  70.25  1,203.00             1,179.00
#   standard_charge_discounted_cash   62,350.00 190.05  152.10 139.81              0.74 12.00 114.70 221.50 106.80  1,203.00             1,191.00
#   standard_charge_negotiated_dollar 40,743.00 105.13   36.83 430.58              4.10  0.95  31.31  39.66   8.35  9,146.00             9,145.05
#   standard_charge_min               72,437.00  49.73   30.15  48.74              0.98  0.95  22.70  72.36  49.66    550.00               549.05
#   standard_charge_max               73,689.00 345.16  185.00 961.56              2.79 24.00  72.36 210.60 138.24 15,779.00            15,755.00
#
# CPT_CODE: 97110
#                                         count   mean  median    std  cv_std_over_mean   min    q25    q75    iqr       max  range_max_minus_min
#   standard_charge_gross             59,258.00 289.17  234.00 157.02              0.54 47.55 219.58 290.45  70.87  1,261.00             1,213.45
#   standard_charge_discounted_cash   57,967.00 216.78  152.10 181.51              0.84 22.60 135.85 229.37  93.52  1,261.00             1,238.40
#   standard_charge_negotiated_dollar 38,474.00  61.02   30.45 354.54              5.81  0.95  26.35  32.95   6.60  9,146.00             9,145.05
#   standard_charge_min               68,287.00  48.75   24.32  57.47              1.18  0.95  22.70  58.37  35.67    550.00               549.05
#   standard_charge_max               69,503.00 302.04  209.00 870.45              2.88 20.03  53.85 234.00 180.15 16,075.00            16,054.97
#
# UNKNOWN
#
# CPT_CODE: 90853
#                                         count   mean  median      std  cv_std_over_mean   min    q25    q75    iqr       max  range_max_minus_min
#   standard_charge_gross             11,070.00 353.48  339.00    95.93              0.27 93.45 339.00 339.00   0.00  2,299.00             2,205.55
#   standard_charge_discounted_cash   11,070.00 228.41  210.18    93.42              0.41 50.12 210.18 210.18   0.00  2,299.00             2,248.88
#   standard_charge_negotiated_dollar    632.00 303.47  193.10   341.45              1.13 58.00 154.00 288.20 134.20  3,366.00             3,308.00
#   standard_charge_min               11,061.00 188.89  210.18    59.34              0.31  6.35 210.18 210.18   0.00    694.00               687.65
#   standard_charge_max               11,061.00 541.21  339.00 2,073.13              3.83 28.80 339.00 339.00   0.00 81,319.00            81,290.20
#
# CPT_CODE: 36556
#                                        count      mean    median       std  cv_std_over_mean      min      q25       q75       iqr        max  range_max_minus_min
#   standard_charge_gross             3,475.00  3,784.55  2,994.00  3,713.60              0.98 1,585.95 2,994.00  3,580.00    586.00 116,584.87           114,998.92
#   standard_charge_discounted_cash   3,475.00  2,264.39  1,856.28  1,307.88              0.58   577.53 1,856.28  1,856.28      0.00  24,482.82            23,905.29
#   standard_charge_negotiated_dollar 2,522.00 16,986.20 12,854.00 11,366.22              0.67 1,154.40 7,861.00 25,450.00 17,589.00  54,269.42            53,115.02
#   standard_charge_min               8,156.00  4,466.13  1,856.28  5,424.50              1.21    62.35 1,856.28  6,434.00  4,577.72  44,584.00            44,521.65
#   standard_charge_max               8,156.00 21,344.01 11,601.00 25,943.67              1.22   258.00 2,994.00 37,268.00 34,274.00 613,983.00           613,725.00
#
# SELF PAY
#
# CPT_CODE: 20610
#                                        count     mean   median      std  cv_std_over_mean    min    q25      q75      iqr        max  range_max_minus_min
#   standard_charge_gross             1,691.00 1,884.72 1,102.44 4,765.84              2.53 407.03 753.80 1,754.90 1,001.10 121,765.90           121,358.87
#   standard_charge_discounted_cash   1,691.00 1,677.91 1,102.44 1,603.74              0.96 162.81 753.80 1,699.31   945.51  25,570.84            25,408.03
#   standard_charge_negotiated_dollar   586.00   963.44   357.16 1,677.39              1.74  81.88 268.29 1,130.70   862.41  21,917.86            21,835.98
#   standard_charge_min               1,667.00   259.31   159.12   299.68              1.16  22.73  88.55   258.90   170.35   2,288.25             2,265.52
#   standard_charge_max               1,667.00 2,113.45   797.65 4,001.40              1.89  83.21 181.40 3,247.26 3,065.86  91,324.42            91,241.21
#
# CPT_CODE: 32551
#                                        count     mean   median      std  cv_std_over_mean      min      q25      q75      iqr       max  range_max_minus_min
#   standard_charge_gross             1,540.00 3,222.53 2,922.29 3,368.12              1.05 1,284.02 2,443.69 3,208.96   765.27 75,043.87            73,759.85
#   standard_charge_discounted_cash   1,540.00 3,023.07 2,922.29   992.32              0.33 1,052.12 2,443.69 3,208.96   765.27 13,507.90            12,455.78
#   standard_charge_negotiated_dollar   541.00 2,029.47 1,879.59 1,453.73              0.72   199.57 1,107.12 2,544.06 1,436.94 13,507.90            13,308.33
#   standard_charge_min               1,528.00   764.94   648.31   482.21              0.63    38.52   478.96 1,052.57   573.61  3,976.22             3,937.70
#   standard_charge_max               1,528.00 4,540.03 3,028.02 6,361.16              1.40   202.81   687.21 4,542.03 3,854.82 56,282.90            56,080.09

# %% [markdown]
# ---
#
# ## 💰 **Part D: Price Summary by Specialty**
#
# **Goal:** Compute mean, median, and standard deviation of all numeric charge columns across each specialty.
# Helps identify which specialties have higher or more variable pricing patterns.
#
# ---

# %%
# ======================================= PART D — PRICE SUMMARY BY SPECIALTY =======================================
# ✅ In summary:
# This block:
# - Prints a header for Part D: summarizing pricing metrics by medical specialty.
# - Selects relevant numeric columns (charges and rates) from the dataframe.
# - Ensures columns exist before analysis and converts text-based numeric columns safely.
# - Groups the data by specialty and computes mean, median, and standard deviation for each numeric column.
# - Creates a clean summary table with flattened column names for readability.
# - Identifies top specialties based on:
#     • Highest average negotiated prices
#     • Highest average Rate_using_max values
#     • Highest variability (standard deviation) in both negotiated prices and Rate_using_max
# - Handles missing or absent columns gracefully and completes with a success message.

print("\n" + "="*100)
print("PART D — PRICE SUMMARY BY SPECIALTY")
print("="*100)

# Define numeric columns of interest
num_cols = [
    "standard_charge_gross",
    "standard_charge_discounted_cash",
    "standard_charge_negotiated_dollar",
    "standard_charge_min",
    "standard_charge_max",
    "Rate_using_min",
    "Rate_using_max"  # <- you kept this
]

# Only include numeric columns that actually exist in the dataframe
existing_num_cols = [c for c in num_cols if c in df.columns]

# Convert Rate_using_max to numeric (if it's stored as text) to avoid aggregation errors
if "Rate_using_max" in df.columns:
    df["Rate_using_max"] = pd.to_numeric(df["Rate_using_max"], errors="coerce")

# Run the specialty-level summary only if both specialty and numeric columns exist
if "specialty" in df.columns and existing_num_cols:

    # Compute mean, median, and std for each specialty across all numeric columns
    specialty_summary = (
        df.groupby("specialty")[existing_num_cols]
          .agg(["mean", "median", "std"])
          .round(2)
    )

    # Flatten multi-level columns into readable single-level names
    specialty_summary.columns = [f"{col}_{stat}" for col, stat in specialty_summary.columns]
    specialty_summary = specialty_summary.reset_index()

    # Display full summary
    print("\n→ Mean, Median, and Standard Deviation of price metrics by specialty:")
    print(indent(specialty_summary.to_string(index=False), "  "))

    # ---- Top specialties by average negotiated price (if column exists)
    if "standard_charge_negotiated_dollar_mean" in specialty_summary.columns:
        top_specialties = (
            specialty_summary.sort_values("standard_charge_negotiated_dollar_mean", ascending=False)
            [["specialty", "standard_charge_negotiated_dollar_mean"]]
            .head(10)
        )
        print("\n→ Top 10 specialties by average negotiated price:")
        print(indent(top_specialties.to_string(index=False), "  "))

    # ---- Top specialties by average Rate_using_max (if available)
    if "Rate_using_max_mean" in specialty_summary.columns:
        top_rum = (
            specialty_summary.sort_values("Rate_using_max_mean", ascending=False)
            [["specialty", "Rate_using_max_mean"]]
            .head(10)
        )
        print("\n→ Top 10 specialties by average Rate_using_max:")
        print(indent(top_rum.to_string(index=False), "  "))

    # ---- Specialties with highest variability (std) in negotiated prices
    if "standard_charge_negotiated_dollar_std" in specialty_summary.columns:
        var_specialties = (
            specialty_summary.sort_values("standard_charge_negotiated_dollar_std", ascending=False)
            [["specialty", "standard_charge_negotiated_dollar_std"]]
            .head(10)
        )
        print("\n→ Specialties with highest variability (std) in negotiated prices:")
        print(indent(var_specialties.to_string(index=False), "  "))

    # ---- Specialties with highest variability (std) in Rate_using_max
    if "Rate_using_max_std" in specialty_summary.columns:
        var_rum = (
            specialty_summary.sort_values("Rate_using_max_std", ascending=False)
            [["specialty", "Rate_using_max_std"]]
            .head(10)
        )
        print("\n→ Specialties with highest variability (std) in Rate_using_max:")
        print(indent(var_rum.to_string(index=False), "  "))

else:
    # Handle missing columns gracefully
    print("⚠️ Missing 'specialty' column or no numeric charge columns found.")

# Final success message
print("\n✅ Part D complete.")
# Out:
# ====================================================================================================
# PART D — PRICE SUMMARY BY SPECIALTY
# ====================================================================================================
#
# → Mean, Median, and Standard Deviation of price metrics by specialty:
#                            specialty  standard_charge_gross_mean  standard_charge_gross_median  standard_charge_gross_std  standard_charge_discounted_cash_mean  standard_charge_discounted_cash_median  standard_charge_discounted_cash_std  standard_charge_negotiated_dollar_mean  standard_charge_negotiated_dollar_median  standard_charge_negotiated_dollar_std  standard_charge_min_mean  standard_charge_min_median  standard_charge_min_std  standard_charge_max_mean  standard_charge_max_median  standard_charge_max_std
#                           Cardiology                   35,500.41                     34,862.00                  32,760.98                             24,864.54                               18,915.60                            26,951.58                               15,085.48                                 11,383.44                              41,873.00                  9,904.36                    7,438.00                11,508.25                 32,930.02                   23,804.00               178,391.32
#                          Dermatology                    1,872.29                        837.00                   4,722.68                                948.85                                  544.05                             1,813.07                                3,112.19                                  1,104.61                               7,129.60                  1,764.13                    1,691.00                 1,433.78                  9,636.08                    7,108.00                16,784.32
#                   Emergency Medicine                    3,511.03                      2,749.00                   3,380.40                              2,637.99                                1,785.55                             2,464.38                                2,777.62                                  1,234.00                               6,509.68                  1,866.36                    1,234.00                 2,750.55                  7,425.27                    2,994.00                17,225.76
#                         Neurosurgery                   20,696.21                     17,323.00                  29,303.61                             10,202.01                                8,265.18                             7,781.87                               10,248.43                                  7,101.00                              21,595.59                  4,581.41                    3,792.00                 3,581.69                 19,494.73                   11,659.00                68,194.97
#                        Ophthalmology                    7,034.37                        664.00                   9,828.99                              3,004.58                                  411.68                             3,709.69                                5,428.76                                  2,702.00                              21,757.28                  2,186.75                    1,871.00                 1,741.68                 12,206.54                    7,108.00                70,537.23
#                   Orthopedic Surgery                    6,230.36                      1,564.00                  14,912.96                              3,130.55                                1,113.45                             5,624.35                                6,347.74                                  2,050.00                              31,597.09                  2,853.93                    1,829.00                 3,642.01                 17,367.72                    8,503.00               134,036.43
#                    Pediatric Surgery                   20,030.69                     20,508.21                  16,699.17                             11,032.89                               13,124.64                             4,537.75                                9,743.31                                  7,108.00                               9,260.09                  3,962.70                    3,242.00                 2,863.63                 17,160.85                   11,847.00                12,994.78
#   Physical Medicine & Rehabilitation                      343.89                        274.00                     242.09                                253.27                                  178.10                               245.87                                  227.75                                    104.12                                 940.95                     76.37                       34.20                    78.11                    376.53                      210.60                 1,051.71
#                Psychiatry/Psychology                      452.38                        376.65                     236.16                                294.24                                  257.30                               170.75                                  623.67                                    231.77                               2,199.34                    219.98                      210.18                   102.04                    675.52                      339.00                 4,964.74
#                   Radiation Oncology                    7,184.07                      6,295.00                   6,763.19                              4,464.52                                3,902.90                             4,493.25                                4,142.47                                  1,533.60                              13,146.68                  2,955.26                    1,669.15                 3,504.27                  8,399.63                    5,671.00                35,230.61
#                              Urology                   12,418.16                      6,697.00                  16,431.81                              6,404.61                                4,152.14                             6,082.18                                8,914.31                                  5,621.00                              25,684.82                  4,119.78                    3,242.00                 3,571.21                 18,944.74                   12,283.00                95,892.19
#
# → Top 10 specialties by average negotiated price:
#               specialty  standard_charge_negotiated_dollar_mean
#              Cardiology                               15,085.48
#            Neurosurgery                               10,248.43
#       Pediatric Surgery                                9,743.31
#                 Urology                                8,914.31
#      Orthopedic Surgery                                6,347.74
#           Ophthalmology                                5,428.76
#      Radiation Oncology                                4,142.47
#             Dermatology                                3,112.19
#      Emergency Medicine                                2,777.62
#   Psychiatry/Psychology                                  623.67
#
# → Specialties with highest variability (std) in negotiated prices:
#               specialty  standard_charge_negotiated_dollar_std
#              Cardiology                              41,873.00
#      Orthopedic Surgery                              31,597.09
#                 Urology                              25,684.82
#           Ophthalmology                              21,757.28
#            Neurosurgery                              21,595.59
#      Radiation Oncology                              13,146.68
#       Pediatric Surgery                               9,260.09
#             Dermatology                               7,129.60
#      Emergency Medicine                               6,509.68
#   Psychiatry/Psychology                               2,199.34
#
# ✅ Part D complete.

# %% [markdown]
# ---
#
# ## 🧹 **Part F: Outlier Handling & Group-Level Summaries**
#
# **Goal:**
# - Clean numeric columns by removing placeholder values and **winsorizing (1st–99th pct)** *within each hospital* to control extreme outliers while preserving real variation.
# - Normalize categorical fields (**bucket**, **setting**, **specialty**) for consistent grouping.
#
# **Then compute summaries (mean, median, std, count) by:**
# - **CPT code**
# - **Payer bucket**
# - **Specialty**
# - **Care setting**
# - **Hospital × Bucket**
# - **CPT code × Bucket**
#
# ---

# %%
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")  # Display floats with commas & 2 decimals

# --- helper: case/space-insensitive column matcher ------------------------------------
def _norm(s: str) -> str:
    return str(s).strip().lower().replace(" ", "_")

def find_present(df, desired_names):
    """
    Given a DataFrame and a list of desired column names (each item can be a string
    or a list of alias strings), return the list of actual DF column names that match
    the first alias found for each desired item. Matching is case/space-insensitive.
    """
    present = []
    df_map = {_norm(c): c for c in df.columns}  # normalized -> actual
    for d in desired_names:
        aliases = [d] if isinstance(d, str) else d
        # try each alias normalized
        for a in aliases:
            a_norm = _norm(a)
            if a_norm in df_map:
                present.append(df_map[a_norm])
                break  # take the first alias that exists
    return present

# ---------------------------------------------------------------
# 0) Columns setup (robust to missing columns)
# ---------------------------------------------------------------
# Find rate columns even if named with different cases/spaces/aliases
rate_cols = find_present(df, [["Rate_using_min","rate_using_min"],
                              ["Rate_using_max","rate_using_max"]])

# Identify other numeric charge columns using common aliases
extra_numeric = find_present(
    df,
    [
        ["standard_charge_gross","gross","list_price","standard_gross"],
        ["standard_charge_discounted_cash","cash_price","discounted_cash","self_pay"],
        ["standard_charge_min","min_rate","negotiated_min"],
        ["standard_charge_max","max_rate","negotiated_max"],
    ],
)

# Final numeric list: rates + any extra numeric columns not already included
num_cols = rate_cols + [c for c in extra_numeric if c not in rate_cols]

# Identify needed categorical columns using aliases
cat_needed = find_present(
    df,
    [
        ["hospital_name","hospital","facility_name"],
        ["bucket","payer_bucket","payer_type"],
        ["specialty","service_line","dep_specialty"],
        ["setting","place_of_service","inpatient_outpatient"],
        ["cpt_code","cpt","hcpcs","hcpcs_code","code"],
    ],
)

# Warn if any canonical categorical columns are missing
missing_cats = set(["hospital_name","bucket","specialty","setting","cpt_code"]) - set(
    [_norm(c) for c in cat_needed]
)
if missing_cats:
    print(f"⚠️ Missing categorical columns (canonical names): {sorted(missing_cats)}")

print(f"Using rate columns: {rate_cols}")
print(f"Using numeric columns: {num_cols}")

# ---------------------------------------------------------------
# 1) Light cleaning: remove placeholders so they don't affect quantiles
#    (coerce to numeric first so comparisons work even if strings)
# ---------------------------------------------------------------
PLACEHOLDER_BIG = 999_999_999.0
df_cap = df.copy()

for col in num_cols:
    # Ensure numeric; invalid parses become NaN
    df_cap[col] = pd.to_numeric(df_cap[col], errors="coerce")
    # Drop non-positive values (<=0) as invalid for pricing
    df_cap.loc[df_cap[col] <= 0, col] = np.nan
    # Remove extreme placeholder sentinel value
    df_cap.loc[df_cap[col] == PLACEHOLDER_BIG, col] = np.nan

# ---------------------------------------------------------------
# 2) Groupwise winsorization (1st–99th pct) WITHIN EACH HOSPITAL
# ---------------------------------------------------------------
def winsorize_series(s, p_low=0.01, p_high=0.99):
    """
    Clip values to the [p_low, p_high] quantile range.
    If fewer than 5 non-null values, skip clipping (return as-is).
    """
    s = pd.to_numeric(s, errors="coerce")
    if s.notna().sum() < 5:  # too few points; skip
        return s
    ql, qh = s.quantile([p_low, p_high])
    return s.clip(lower=ql, upper=qh)

impact_rows = []

# find actual hospital_name column used above (via aliases)
hospital_col = find_present(df_cap, [["hospital_name","hospital","facility_name"]])
hospital_col = hospital_col[0] if hospital_col else None

if hospital_col:
    # Winsorize within each hospital to preserve cross-hospital variation
    for col in num_cols:
        before = df_cap[col].copy()
        df_cap[col] = (
            df_cap.groupby(hospital_col, group_keys=False)[col]
                  .apply(winsorize_series)
        )
        # Count how many values changed due to clipping
        changed = (before.notna() & df_cap[col].notna() & (before != df_cap[col])).sum()
        impact_rows.append([col, int(before.notna().sum()), int(changed),
                            float(before.quantile(0.01)), float(before.quantile(0.99))])
else:
    # Fallback: global winsorization if hospital name missing
    for col in num_cols:
        before = df_cap[col].copy()
        df_cap[col] = winsorize_series(df_cap[col])
        changed = (before.notna() & df_cap[col].notna() & (before != df_cap[col])).sum()
        impact_rows.append([col, int(before.notna().sum()), int(changed),
                            float(before.quantile(0.01)), float(before.quantile(0.99))])

# Build and print an impact report showing how many values were capped
impact = pd.DataFrame(
    impact_rows, columns=["column", "n_non_null", "n_capped", "global_q01", "global_q99"]
).set_index("column")
print("\n" + "-"*100)
print("Outlier treatment (winsorization within hospital):")
print(indent(impact.round(2).to_string(), " "))

# ---------------------------------------------------------------
# 3) Helper to summarize groups
# ---------------------------------------------------------------
def group_summary(df_in, group_cols, value_cols):
    """
    Resolve group column aliases, verify availability, then compute grouped
    mean/median/std/count for the given value columns. Returns a DataFrame,
    or a warning string if required columns are missing.
    """
    # resolve group columns using the same finder
    resolved_groups = find_present(df_in, group_cols)
    if len(resolved_groups) != len(group_cols):
        missing = [gc for gc in group_cols if gc not in resolved_groups]
        return f"⚠️ Skipped {group_cols} — missing after resolution: {missing}"
    vals_present = [c for c in value_cols if c in df_in.columns]
    if not vals_present:
        return f"⚠️ No value columns present among {value_cols}"
    out = (
        df_in.groupby(resolved_groups)[vals_present]
             .agg(["mean", "median", "std", "count"])
             .round(2)
    )
    return out

####################################################################
# ---------------------------------------------------------------
# 3.5) Normalize category values so 'both', 'Both', 'BOTH' group together
# ---------------------------------------------------------------
def norm_cat(x: str) -> str:
    """Lowercase, trim, and standardize separators so categorical labels group cleanly."""
    if pd.isna(x): 
        return np.nan
    s = str(x).strip().lower().replace("-", " ").replace("_", " ")
    s = " ".join(s.split())  # collapse multiple spaces
    return s

# Canonical maps for consistent grouping
setting_map = {
    "inpatient": "inpatient",
    "outpatient": "outpatient",
    "both": "both",
}

bucket_map = {
    "commercial": "commercial",
    "government": "government",
    "other government": "government",  # optional: fold into government if you prefer
    "self pay": "self pay",
    "self-pay": "self pay",
    "selfpay": "self pay",
    "unknown": "unknown",
}

# Specialty canonicalization (use the six you listed)
specialty_map = {
    "dermatology": "dermatology",
    "ophthalmology": "ophthalmology",
    "orthopedics": "orthopedics",
    "physical medicine and rehabilitation": "physical medicine and rehabilitation",
    "psychiatry/psychology": "psychiatry/psychology",
    "radiation oncology": "radiation oncology",
}

# Create normalized columns (leave originals untouched)
if "setting" in df_cap.columns:
    df_cap["setting_norm"] = df_cap["setting"].map(lambda v: setting_map.get(norm_cat(v), norm_cat(v)))

if "bucket" in df_cap.columns:
    df_cap["bucket_norm"] = df_cap["bucket"].map(lambda v: bucket_map.get(norm_cat(v), norm_cat(v)))

if "specialty" in df_cap.columns:
    df_cap["specialty_norm"] = df_cap["specialty"].map(lambda v: specialty_map.get(norm_cat(v), norm_cat(v)))

# ---------------------------------------------------------------
# 4) Produce the tables you asked for
# ---------------------------------------------------------------
tables = {}
tables["by_cpt_code"]        = group_summary(df_cap, ["cpt_code"], rate_cols)
tables["by_bucket"]          = group_summary(df_cap, ["bucket_norm"], rate_cols)
tables["by_specialty"]       = group_summary(df_cap, ["specialty_norm"], rate_cols)
tables["by_setting"]         = group_summary(df_cap, ["setting_norm"], rate_cols)
tables["by_hospital_bucket"] = group_summary(df_cap, ["hospital_name", "bucket_norm"], rate_cols)
tables["by_cpt_bucket"]      = group_summary(df_cap, ["cpt_code", "bucket_norm"], rate_cols)

# ---------------------------------------------------------------
# 5) Display nicely (no files written)
# ---------------------------------------------------------------
for name, tbl in tables.items():
    print("\n" + "="*100)
    print(name.replace("_", " ").upper())
    print("="*100)
    if isinstance(tbl, str):
        # If a warning string was returned (missing columns), print it
        print(tbl)  # message about missing columns
    else:
        # Show first 20 rows of each summary table, indented for readability
        print(indent(tbl.head(20).to_string(), " "))
# Out:
# Using rate columns: ['rate_using_min', 'rate_using_max']
# Using numeric columns: ['rate_using_min', 'rate_using_max', 'standard_charge_gross', 'standard_charge_discounted_cash', 'standard_charge_min', 'standard_charge_max']
#
# ----------------------------------------------------------------------------------------------------
# Outlier treatment (winsorization within hospital):
#                                   n_non_null  n_capped  global_q01  global_q99
#  column
#  rate_using_min                     10154885    170110       18.00   39,669.00
#  rate_using_max                     10154885    162089       23.11   63,529.00
#  standard_charge_gross               4508970     25335      108.00   90,150.00
#  standard_charge_discounted_cash     4452892     24031       50.95   55,893.00
#  standard_charge_min                 9668019    122947       11.68   24,444.12
#  standard_charge_max                 9721835    112449       28.76   66,542.00
#
# ====================================================================================================
# BY CPT CODE
# ====================================================================================================
#           rate_using_min                           rate_using_max
#                     mean   median      std   count           mean    median       std   count
#  cpt_code
#  10040          2,510.30 1,871.00 3,538.15   77748      10,208.90  7,108.00 11,592.32   77748
#  11102          1,995.20 1,460.10 3,339.44  122799       6,947.95  2,702.00 10,394.80  122799
#  11104          2,172.09 1,638.00 3,305.30  116139       7,318.80  2,730.91 10,545.24  116139
#  11900          2,190.98 1,678.00 3,716.80  103973       8,002.80  3,242.00 11,238.71  103973
#  12002          1,976.62 1,548.00 3,575.53  123164       6,976.80  1,986.00 10,470.29  123164
#  14040          3,211.38 2,628.00 3,563.55   94428      10,085.56  7,108.00 17,777.87   94428
#  15781          2,801.43 2,250.00 3,522.46   75076      10,898.25  7,108.00 11,551.77   75076
#  17000          2,222.46 1,728.00 3,529.99   84092       9,344.15  6,972.00 11,917.54   84092
#  17003          2,295.91 1,829.00 3,539.16   82296       9,459.76  7,108.00 11,653.27   82296
#  17110          2,134.25 1,638.00 3,650.45  110469       7,655.50  3,242.00 11,076.30  110469
#  20600          1,844.64   962.00 3,510.39  154389       6,455.48  1,740.84 10,510.35  154389
#  20605          1,780.84   962.00 3,438.41  160449       6,203.26  1,541.70 10,353.37  160449
#  20610          1,654.62   962.00 3,257.07  183186       5,499.08  1,102.44  9,698.83  183186
#  20611          1,992.67 1,659.12 3,369.48  160323       6,478.36  2,676.00  9,975.09  160323
#  21743          4,453.99 3,242.00 4,208.65   72854      14,065.96 11,556.00 11,511.00   72854
#  22630          7,017.81 6,140.00 4,637.46   79286      15,696.52 11,796.00 12,272.31   79286
#  26055          3,498.01 2,702.00 3,548.48   90008      10,815.01  7,108.00 24,705.82   90008
#  27130          6,819.16 3,242.00 8,203.17   83078      23,581.70 29,997.00 16,725.42   83078
#  27447          8,048.29 3,242.00 8,512.34   86752      23,908.16 21,506.85 15,694.64   86752
#  29826          5,614.05 3,788.60 6,231.24   99525      19,366.12 15,007.00 21,050.02   99525
#
# ====================================================================================================
# BY BUCKET
# ====================================================================================================
#              rate_using_min                            rate_using_max
#                        mean   median      std    count           mean   median       std    count
#  bucket_norm
#  commercial        4,350.62 1,728.00 7,828.98  5221287       8,754.97 2,702.00 21,183.06  5221287
#  government        3,505.38 1,950.00 4,989.97  4417713      11,030.04 5,671.00 25,982.38  4417713
#  self pay          4,177.33 1,097.09 8,857.59    19349       5,006.84 1,097.09 12,028.18    19349
#  unknown           5,206.45 2,702.00 7,562.98   496517      11,532.57 5,871.00 30,047.49   496517
#
# ====================================================================================================
# BY SPECIALTY
# ====================================================================================================
#                                     rate_using_min                             rate_using_max
#                                               mean   median       std    count           mean    median       std    count
#  specialty_norm
#  cardiology                              12,625.88 9,435.00 12,764.92  1069701      22,432.34 15,098.86 40,734.65  1069701
#  dermatology                              2,307.67 1,829.00  3,512.96   887041       8,468.11  3,609.00 12,073.52   887041
#  emergency medicine                       2,713.42 1,678.00  3,890.53  1253262       6,094.53  2,749.00 10,932.95  1253262
#  neurosurgery                             5,702.44 4,664.50  5,323.87   818128      16,159.57 11,217.00 28,811.83   818128
#  ophthalmology                            2,804.05 2,001.00  3,677.09   386208       9,634.45  6,140.00 29,619.52   386208
#  orthopedic surgery                       4,079.08 2,250.00  5,908.56  1232019      12,572.61  6,696.72 30,946.62  1232019
#  pediatric surgery                        5,048.47 3,242.00  4,965.47   753259      15,398.46 11,217.00 12,723.58   753259
#  physical medicine & rehabilitation         190.95   110.00    626.33  1610882         227.26    130.54    711.91  1610882
#  psychiatry/psychology                      307.78   231.77    596.51   804971         413.34    339.00  1,991.16   804971
#  radiation oncology                       4,059.95 2,610.00  5,717.61   392157       5,841.37  3,141.50 15,717.37   392157
#  urology                                  5,478.96 3,366.00  5,633.08   947257      14,882.51 11,200.00 29,261.11   947257
#
# ====================================================================================================
# BY SETTING
# ====================================================================================================
#               rate_using_min                            rate_using_max
#                         mean   median      std    count           mean   median       std    count
#  setting_norm
#  both               2,354.18   301.28 6,020.17  1053448       2,371.79   302.40  6,063.32  1053448
#  inpatient          3,758.72   431.00 8,997.86  1112501       6,214.27   748.00 14,531.53  1112501
#  outpatient         4,281.67 2,350.00 6,432.82  7988936      11,372.09 6,140.00 26,058.40  7988936
#
# ====================================================================================================
# BY HOSPITAL BUCKET
# ====================================================================================================
#                                            rate_using_min                           rate_using_max
#                                                      mean   median       std  count           mean   median       std  count
#  hospital_name                 bucket_norm
#  AdventHealth Carollwood       commercial        5,559.23 1,216.00 10,251.26  11682       6,525.78 1,485.00 11,933.19  11682
#                                government        3,738.34   975.00  7,804.23   9204       4,962.65 1,224.00 10,531.04   9204
#                                unknown           4,460.73   975.00  8,869.07   1062       7,180.48 1,917.00 12,674.08   1062
#  AdventHealth Dade City        commercial        8,254.24 1,614.00 16,483.72   3984       8,254.24 1,614.00 16,483.72   3984
#                                government        2,294.45   694.00  5,223.27   2457       2,294.45   694.00  5,223.27   2457
#                                unknown           6,342.91 1,373.00 12,792.04    269       6,342.91 1,373.00 12,792.04    269
#  AdventHealth Daytona Beach    commercial        4,610.14   562.00 10,776.36  12390       5,568.82   663.00 13,422.37  12390
#                                government        2,876.13   459.00  7,511.06   9204       4,578.79   727.00 12,381.58   9204
#                                self pay          5,671.00   681.00 12,479.48    354       6,051.21   681.00 14,070.21    354
#                                unknown           5,419.15   663.00 12,071.27    708       5,728.99   663.00 13,437.80    708
#  AdventHealth DeLand           commercial        4,145.53   465.00 10,730.88   7682       5,690.74   748.00 14,825.33   7682
#                                government        3,131.97   433.00  8,483.06   4843       5,229.89   845.00 14,230.85   4843
#                                self pay          5,136.86   615.00 12,463.78    167       5,572.90   615.00 14,409.62    167
#                                unknown           4,125.29   419.00 10,832.97    668       5,549.25   754.00 14,129.26    668
#  AdventHealth Fish Memorial    commercial        4,774.80   626.00 11,096.83  12390       5,638.53   718.00 13,671.19  12390
#                                government        3,184.66   505.00  8,371.67   8850       4,447.64   710.00 12,012.01   8850
#                                self pay          5,611.33   806.00 12,211.79    354       6,134.56   806.00 14,766.14    354
#                                unknown           5,131.86   672.00 11,572.13   1062       5,451.16   672.00 13,233.15   1062
#  AdventHealth Heart of Florida commercial        5,034.26   867.50 10,910.42  12600       8,220.37 1,350.50 19,904.94  12600
#                                government        2,920.53   519.00  7,599.87  11900       7,917.56 1,334.00 20,690.21  11900
#
# ====================================================================================================
# BY CPT BUCKET
# ====================================================================================================
#                       rate_using_min                          rate_using_max
#                                 mean   median      std  count           mean   median       std  count
#  cpt_code bucket_norm
#  10040    commercial        3,096.21 1,871.00 5,182.64  33265       9,860.50 7,108.00 11,515.98  33265
#           government        2,054.78 1,829.00 1,143.60  39809      10,644.24 7,108.00 11,648.63  39809
#           unknown           2,220.07 2,200.00 1,282.06   4674       8,980.59 3,313.00 11,483.16   4674
#  11102    commercial        2,087.57   962.00 4,360.48  63456       5,723.69 1,248.15  9,690.53  63456
#           government        1,880.53 1,727.00 1,663.03  53441       8,355.93 3,242.00 10,961.63  53441
#           self pay            929.41   955.10   654.02    279         929.41   955.10    654.02    279
#           unknown           2,095.62 2,117.00 1,542.39   5623       7,680.99 3,035.00 10,951.05   5623
#  11104    commercial        2,330.75 1,440.00 4,364.35  58820       6,191.31 1,829.00  9,865.78  58820
#           government        1,996.82 1,829.00 1,591.88  51327       8,608.64 4,549.00 11,106.63  51327
#           self pay            984.55   955.10   835.36    323         984.55   955.10    835.36    323
#           unknown           2,180.50 2,145.00 1,607.30   5669       7,700.05 3,035.00 10,986.24   5669
#  11900    commercial        2,354.64 1,326.00 4,948.73  52078       6,720.43 2,702.00 10,662.15  52078
#           government        2,016.15 1,728.00 1,758.71  46488       9,435.01 7,108.00 11,650.00  46488
#           self pay          1,323.79 1,091.00   903.93     15       1,323.79 1,091.00    903.93     15
#           unknown           2,120.04 1,871.00 1,629.62   5392       8,059.04 3,242.00 11,567.42   5392
#  12002    commercial        2,256.87 1,199.70 4,678.33  64692       5,881.98 1,935.00  9,698.10  64692
#           government        1,644.42 1,638.00 1,608.88  52121       8,338.86 3,242.00 11,190.09  52121
#           self pay            637.39   480.24   460.70    164         637.39   480.24    460.70    164
#           unknown           1,880.08 1,829.00 1,424.60   6186       7,118.75 2,670.00 10,716.00   6186
#  14040    commercial        3,957.64 2,702.00 4,883.32  43887       9,503.14 6,163.20 16,208.49  43887
